# %% [markdown]
# # Client Data Update ETL - Test Notebook
#
# **Purpose**: Test the client_data_update_etl pipeline before deploying to Airflow
#
# **Pipeline Steps**:
# 1. Extract new pool listings (last 2 days)
# 2. Extract removed pool listings (last 2 days)
# 3. Match existing properties in master DB
# 4. Transform - Create property/pool objects
# 5. Transform - Mark removed listings
# 6. Load properties to master DB
# 7. Load pools to master DB
# 8. Load listings to master DB
# 9. Update removed listings in master DB
#
# ---

# %% [markdown]
# ## Setup & Imports

# %%
import sys
import os
from datetime import datetime, timezone
import tempfile

# Add airflow directory to path
sys.path.insert(0, '/home/james/PDS/client_data_feeds/realestate/airflow')

import pandas as pd

# Import pipeline functions
from include.extract.client_data_extract import (
    extract_new_pool_listings,
    extract_removed_pool_listings,
)
from include.transform.client_data_transform import (
    match_existing_properties,
    transform_create_property_pool_objects,
    transform_mark_removed_listings,
)
from include.load.client_data_load import (
    upsert_properties,
    upsert_pools,
    upsert_listings,
    update_removed_listings,
)

print("✓ Imports successful")

# Create working directory
workdir = os.path.join(tempfile.gettempdir(), f"client_data_test_{datetime.now().strftime('%Y%m%d_%H%M%S')}")
os.makedirs(workdir, exist_ok=True)
print(f"✓ Working directory: {workdir}")
# Out:
# ✓ Imports successful
# ✓ Working directory: /tmp/client_data_test_20260128_153428

# %% [markdown]
# ## Step 1: Extract New Pool Listings
#
# Extract all listings added in the last 2 days that have pools.

# %%
result = extract_new_pool_listings(workdir)

print(f"\n✓ Extracted {result['row_count']} new pool listings")
print(f"✓ Saved to: {result['parquet_path']}")

# Load and inspect
if result['row_count'] > 0:
    new_pools_df = pd.read_parquet(result['parquet_path'])
    print(f"\nColumns: {list(new_pools_df.columns)}")
    print(f"\nSample data:")
    print(new_pools_df.head())
    print(f"\nPool type distribution:")
    print(new_pools_df['pool_type'].value_counts())
else:
    print("\n⚠️  No new pool listings found")
# Out:
# /home/james/PDS/client_data_feeds/realestate/airflow/include/extract/client_data_extract.py:68: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn, params=(cutoff_date,))
# ✓ Extracted 1007 new pool listings
# ✓ Saved to: /tmp/client_data_test_20260128_153428/new_pool_listings.parquet
#
# Columns: ['mls_id', 'address_number', 'street_name', 'municipality', 'province_state', 'postal_code', 'lat', 'lon', 'date_collected', 'description', 'bedrooms', 'bathrooms', 'size_sqft', 'stories', 'house_cat', 'price', 'pool_type', 'pool_mentioned']
#
# Sample data:
#       mls_id  address_number          street_name          municipality  \
# 0  X12316017            2229       HOUCK CRESCENT     Fort Erie (Bowen)
# 1   R3072849           20510           48A AVENUE               Langley
# 2  X12507288             699   SEVILLA PARK PLACE  London East (East C)
# 3  X12601652              77         SEVERN DRIVE  Guelph (Grange Road)
# 4   R3080204             822  34909 OLD YALE ROAD            Abbotsford
#
#      province_state postal_code        lat         lon  \
# 0           Ontario      L2A5M4  42.948261  -78.965556
# 1  British Columbia      V3A3P3  49.090194 -122.655384
# 2           Ontario      N5Y4H9  43.012375  -81.235392
# 3           Ontario      N1E7L2  43.573487  -80.213824
# 4  British Columbia      V3G2E7  49.048437 -122.257515
#
#                     date_collected  \
# 0 2026-01-27 02:03:53.616022+00:00
# 1 2026-01-27 02:03:53.616022+00:00
# 2 2026-01-27 02:03:53.616022+00:00
# 3 2026-01-27 02:03:53.616022+00:00
# 4 2026-01-27 02:03:53.616022+00:00
#
#                                          description bedrooms bathrooms  \
# 0  Spacious 1.5 Storey Home on Nearly 5 Acres wit...     None      None
# 1  Own a beautiful home on a large lot in a famil...        5         2
# 2  Charming All-Brick semi- detached Bungalow wit...    3 + 2         2
# 3  77 Severn Drive is strategically located in Gu...        3         3
# 4  This lovely, bright 2-bedroom townhouse offers...        2         2
#
#    size_sqft  stories        house_cat      price pool_type  pool_mentioned
# 0  2734 sqft      NaN     Multi-Family  1400000.0      None            True
# 1  2114 sqft      NaN            House  1495000.0      None            True
# 2     699.99      1.0            House   499000.0      None            True
# 3    1099.99      2.0  Row / Townhouse   720000.0      None            True
# 4  1002 sqft      NaN  Row / Townhouse   396500.0      None            True
#
# Pool type distribution:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Step 2: Extract Removed Pool Listings
#
# Extract all listings removed in the last 2 days that have pools.

# %%
result_removed = extract_removed_pool_listings(workdir)

print(f"\n✓ Extracted {result_removed['row_count']} removed pool listings")
print(f"✓ Saved to: {result_removed['parquet_path']}")

# Load and inspect
if result_removed['row_count'] > 0:
    removed_pools_df = pd.read_parquet(result_removed['parquet_path'])
    print(f"\nColumns: {list(removed_pools_df.columns)}")
    print(f"\nSample data:")
    print(removed_pools_df.head())
else:
    print("\n⚠️  No removed pool listings found")
# Out:
# ✓ Extracted 196 removed pool listings
# ✓ Saved to: /tmp/client_data_test_20260128_153428/removed_pool_listings.parquet
#
# Columns: ['mls_id', 'address_number', 'street_name', 'municipality', 'province_state', 'postal_code', 'lat', 'lon', 'pool_type', 'removal_date']
#
# Sample data:
#       mls_id  address_number             street_name  \
# 0   40670516            8036          SHERIDAN Court
# 1   40790101             150           BENZIGER Lane
# 2  X12714248              49     66 - 49 RHONDA ROAD
# 3  X12407922            1501  228 - 1501 LINE 8 ROAD
# 4   NB128674              62    60-62 Ashworth Drive
#
#                                 municipality province_state postal_code  \
# 0                                    Grassie        Ontario      L0R1M0
# 1                               Stoney Creek        Ontario      L8E6G6
# 2  Guelph (Willow West/Sugarbush/West Acres)        Ontario      N1H7A4
# 3            Niagara-on-the-Lake (Queenston)        Ontario      L0S1L0
# 4                                    Moncton  New Brunswick      E1A6J8
#
#          lat        lon pool_type                     removal_date
# 0  43.152334 -79.613525      None 2026-01-28 17:37:38.583097+00:00
# 1  43.214539 -79.647166      None 2026-01-28 17:37:38.583097+00:00
# 2  43.535423 -80.279132      None 2026-01-28 17:37:38.583097+00:00
# 3  43.172288 -79.064087      None 2026-01-28 17:37:38.583097+00:00
# 4  46.125381 -64.789263      None 2026-01-28 17:37:38.583097+00:00
# /home/james/PDS/client_data_feeds/realestate/airflow/include/extract/client_data_extract.py:141: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn, params=(cutoff_date,))

# %% [markdown]
# ## Step 3: Match Existing Properties
#
# Match new and removed listings against existing properties in master DB.

# %%
match_result = match_existing_properties(
    result['parquet_path'],
    result_removed['parquet_path'],
    workdir
)

print(f"\n✓ New listings matched: {match_result['new_matched_count']}")
print(f"✓ Removed listings matched: {match_result['removed_matched_count']}")

# Load and inspect matched data
new_matched_df = pd.read_parquet(match_result['new_matched_path'])
removed_matched_df = pd.read_parquet(match_result['removed_matched_path'])

print(f"\nNew listings with property match: {new_matched_df['property_id'].notna().sum()}")
print(f"New listings without property match: {new_matched_df['property_id'].isna().sum()}")

print(f"\nRemoved listings with property match: {removed_matched_df['property_id'].notna().sum()}")
print(f"Removed listings without property match: {removed_matched_df['property_id'].isna().sum()}")
# Out:
# Removed listing 40670516 has no property match
# Removed listing 40790101 has no property match
# Removed listing X12714248 has no property match
# Removed listing X12407922 has no property match
# Removed listing NB128674 has no property match
# Removed listing 40756588 has no property match
# Removed listing 40761729 has no property match
# Removed listing 40764452 has no property match
# Removed listing 40766023 has no property match
# Removed listing 40769220 has no property match
# Removed listing R3071010 has no property match
# Removed listing 40782535 has no property match
# Removed listing R3075558 has no property match
# Removed listing 40783881 has no property match
# Removed listing 40785063 has no property match
# Removed listing 40786193 has no property match
# Removed listing 40787819 has no property match
# Removed listing W12385750 has no property match
# Removed listing NB129368 has no property match
# Removed listing R2990216 has no property match
# Removed listing R3068488 has no property match
# Removed listing 40777642 has no property match
# Removed listing X12519420 has no property match
# Removed listing X12360826 has no property match
# Removed listing X12266989 has no property match
# Removed listing R3058911 has no property match
# Removed listing X12558616 has no property match
# Removed listing X9411347 has no property match
# Removed listing 40792683 has no property match
# Removed listing 40795189 has no property match
# Removed listing X12656072 has no property match
# Removed listing X12688442 has no property match
# Removed listing NB123491 has no property match
# Removed listing N12676462 has no property match
# Removed listing NB129426 has no property match
# Removed listing NB130033 has no property match
# Removed listing NB130046 has no property match
# Removed listing NB130122 has no property match
# Removed listing X12409384 has no property match
# Removed listing NB131514 has no property match
# Removed listing W12289378 has no property match
# Removed listing R2958381 has no property match
# Removed listing R2979724 has no property match
# Removed listing R2989112 has no property match
# Removed listing R3015068 has no property match
# Removed listing W12525410 has no property match
# Removed listing W12664504 has no property match
# Removed listing R3025974 has no property match
# Removed listing 40799278 has no property match
# Removed listing X12589666 has no property match
# Removed listing NB128808 has no property match
# Removed listing NB128025 has no property match
# Removed listing NB130080 has no property match
# Removed listing X12404848 has no property match
# Removed listing X12524768 has no property match
# Removed listing X12270494 has no property match
# Removed listing R3071419 has no property match
# Removed listing R3056764 has no property match
# Removed listing R3057196 has no property match
# Removed listing R3067587 has no property match
# Removed listing R3059927 has no property match
# Removed listing 40795614 has no property match
# Removed listing R3060007 has no property match
# Removed listing R3056576 has no property match
# Removed listing X12096573 has no property match
# Removed listing X12615804 has no property match
# Removed listing X12505876 has no property match
# Removed listing R3067420 has no property match
# Removed listing R3047871 has no property match
# Removed listing R3074481 has no property match
# Removed listing R3068765 has no property match
# Removed listing X12657572 has no property match
# Removed listing R3073266 has no property match
# Removed listing X12505878 has no property match
# Removed listing R3074133 has no property match
# Removed listing X12412524 has no property match
# Removed listing R3076282 has no property match
# Removed listing R3076458 has no property match
# Removed listing R3079215 has no property match
# Removed listing X12718606 has no property match
# Removed listing 40795974 has no property match
# Removed listing R3064636 has no property match
# Removed listing R3077828 has no property match
# Removed listing X12260788 has no property match
# Removed listing R3079049 has no property match
# Removed listing R3078127 has no property match
# Removed listing R3076165 has no property match
# Removed listing X12361259 has no property match
# Removed listing 40755619 has no property match
# Removed listing R3059033 has no property match
# Removed listing R3059947 has no property match
# Removed listing R3069630 has no property match
# Removed listing R3016403 has no property match
# Removed listing R3041392 has no property match
# Removed listing R3075700 has no property match
# Removed listing 40795541 has no property match
# Removed listing NB124726 has no property match
# Removed listing W12636724 has no property match
# Removed listing 40775282 has no property match
# Removed listing W12671444 has no property match
# Removed listing 40796239 has no property match
# Removed listing W12467929 has no property match
# Removed listing X12290222 has no property match
# Removed listing X12290247 has no property match
# Removed listing X12348210 has no property match
# Removed listing X12399486 has no property match
# Removed listing X12630592 has no property match
# Removed listing W12438937 has no property match
# Removed listing X12450394 has no property match
# Removed listing X9420137 has no property match
# Removed listing X12501560 has no property match
# Removed listing X12511270 has no property match
# Removed listing W12272936 has no property match
# Removed listing X12565068 has no property match
# Removed listing X12585362 has no property match
# Removed listing X12600346 has no property match
# Removed listing X12609484 has no property match
# Removed listing X12671120 has no property match
# Removed listing X12482242 has no property match
# Removed listing X12702010 has no property match
# Removed listing X12553126 has no property match
# Removed listing W12693012 has no property match
# Removed listing X12430324 has no property match
# Removed listing X12518090 has no property match
# Removed listing R3067133 has no property match
# Removed listing X12644512 has no property match
# Removed listing R2990917 has no property match
# Removed listing 40775688 has no property match
# Removed listing 40794783 has no property match
# Removed listing X12540990 has no property match
# Removed listing W12689318 has no property match
# Removed listing X12445422 has no property match
# Removed listing 40781285 has no property match
# Removed listing X12477851 has no property match
# Removed listing X12524532 has no property match
# Removed listing X12614398 has no property match
# Removed listing X12673696 has no property match
# Removed listing 40799115 has no property match
# Removed listing X12703566 has no property match
# Removed listing 40795577 has no property match
# Removed listing 40784471 has no property match
# Removed listing X12537936 has no property match
# Removed listing X12647656 has no property match
# Removed listing X12678864 has no property match
# Removed listing X12510138 has no property match
# Removed listing X12423009 has no property match
# Removed listing 40791766 has no property match
# Removed listing 40768478 has no property match
# Removed listing X12397641 has no property match
# Removed listing X10425532 has no property match
# Removed listing 40793953 has no property match
# Removed listing X12691972 has no property match
# Removed listing X12354516 has no property match
# Removed listing X12463441 has no property match
# Removed listing 40781775 has no property match
# Removed listing X12480419 has no property match
# Removed listing X12433097 has no property match
# Removed listing 40792860 has no property match
# Removed listing 40759060 has no property match
# Removed listing X12339608 has no property match
# Removed listing 40791031 has no property match
# Removed listing X12585130 has no property match
# Removed listing 40795990 has no property match
# Removed listing X12673600 has no property match
# Removed listing X12657172 has no property match
# Removed listing 40793999 has no property match
# Removed listing X12661280 has no property match
# Removed listing X12581562 has no property match
# Removed listing R3077624 has no property match
# Removed listing R3075973 has no property match
# Removed listing X12436573 has no property match
# Removed listing 40796332 has no property match
# Removed listing 40773362 has no property match
# Removed listing X12669672 has no property match
# Removed listing X12637286 has no property match
# Removed listing 40782544 has no property match
# Removed listing X12484298 has no property match
# Removed listing 40776941 has no property match
# Removed listing X12450224 has no property match
# Removed listing X9841793 has no property match
# Removed listing 40786623 has no property match
# Removed listing X12606134 has no property match
# Removed listing 40780998 has no property match
# Removed listing 40797833 has no property match
# Removed listing X12678156 has no property match
# Removed listing X12438410 has no property match
# Removed listing X12685202 has no property match
# Removed listing X12655568 has no property match
# Removed listing X12435193 has no property match
# Removed listing X12690706 has no property match
# Removed listing 40772276 has no property match
# Removed listing X12686076 has no property match
# Removed listing X12459147 has no property match
# Removed listing X12678606 has no property match
# Removed listing X12441313 has no property match
# Removed listing X12646884 has no property match
# ✓ New listings matched: 0
# ✓ Removed listings matched: 0
#
# New listings with property match: 0
# New listings without property match: 1007
#
# Removed listings with property match: 0
# Removed listings without property match: 196

# %% [markdown]
# ## Step 4: Transform - Create Property/Pool Objects
#
# Create property and pool records for new listings without existing properties.

# %%
transform_new_result = transform_create_property_pool_objects(
    match_result['new_matched_path'],
    workdir
)

print(f"\n✓ Properties to insert: {transform_new_result['property_count']}")
print(f"✓ Properties file: {transform_new_result['properties_path']}")
print(f"✓ Pools file: {transform_new_result['pools_path']}")
print(f"✓ Listings file: {transform_new_result['listings_path']}")

# Inspect created objects
if transform_new_result['property_count'] > 0:
    properties_df = pd.read_parquet(transform_new_result['properties_path'])
    pools_df = pd.read_parquet(transform_new_result['pools_path'])
    listings_df = pd.read_parquet(transform_new_result['listings_path'])
    
    print(f"\nProperties sample:")
    print(properties_df.head())
    
    print(f"\nPools sample:")
    print(pools_df.head())
    
    print(f"\nListings sample:")
    print(listings_df[['mls_id', 'price', 'bedrooms', 'bathrooms']].head())
# Out:
# ✓ Properties to insert: 1007
# ✓ Properties file: /tmp/client_data_test_20260128_153428/properties_to_insert.parquet
# ✓ Pools file: /tmp/client_data_test_20260128_153428/pools_to_insert.parquet
# ✓ Listings file: /tmp/client_data_test_20260128_153428/listings_to_insert.parquet
#
# Properties sample:
#             address_id  address_number          street_name  \
# 0  8848708115112578671            2229       HOUCK CRESCENT
# 1  4417291561433416372           20510           48A AVENUE
# 2   661525098263364484             699   SEVILLA PARK PLACE
# 3  1429104246350380139              77         SEVERN DRIVE
# 4  7821956053121296324             822  34909 OLD YALE ROAD
#
#            municipality    province_state postal_code        lat         lon  \
# 0     Fort Erie (Bowen)           Ontario      L2A5M4  42.948261  -78.965556
# 1               Langley  British Columbia      V3A3P3  49.090194 -122.655384
# 2  London East (East C)           Ontario      N5Y4H9  43.012375  -81.235392
# 3  Guelph (Grange Road)           Ontario      N1E7L2  43.573487  -80.213824
# 4            Abbotsford  British Columbia      V3G2E7  49.048437 -122.257515
#
#   country
# 0  Canada
# 1  Canada
# 2  Canada
# 3  Canada
# 4  Canada
#
# Pools sample:
#      address_id pool_type  is_new_property property_id
# 0  8.848708e+18      None             True        None
# 1  4.417292e+18      None             True        None
# 2  6.615251e+17      None             True        None
# 3  1.429104e+18      None             True        None
# 4  7.821956e+18      None             True        None
#
# Listings sample:
#       mls_id      price bedrooms bathrooms
# 0  X12316017  1400000.0     None      None
# 1   R3072849  1495000.0        5         2
# 2  X12507288   499000.0    3 + 2         2
# 3  X12601652   720000.0        3         3
# 4   R3080204   396500.0        2         2

# %% [markdown]
# ## Step 5: Transform - Mark Removed Listings
#
# Prepare updates for removed listings.

# %%
transform_removed_result = transform_mark_removed_listings(
    match_result['removed_matched_path'],
    workdir
)

print(f"\n✓ Listings to mark as removed: {transform_removed_result['update_count']}")
print(f"✓ Updates file: {transform_removed_result['updates_path']}")

# Inspect updates
if transform_removed_result['update_count'] > 0:
    updates_df = pd.read_parquet(transform_removed_result['updates_path'])
    print(f"\nUpdates sample:")
    print(updates_df.head())
# Out:
# 196 removed listings have no property match - skipping
# ✓ Listings to mark as removed: 0
# ✓ Updates file: /tmp/client_data_test_20260128_153428/listings_to_update.parquet

# %% [markdown]
# ## Step 6: Load Properties to Master DB
#
# Upsert properties to master database.

# %%
load_properties_result = upsert_properties(transform_new_result['properties_path'])

property_records = load_properties_result['property_records']

print(f"\n✓ Properties upserted: {len(property_records)}")
print(f"✓ Property records created")

if property_records:
    # Show sample records
    print(f"\nSample property records:")
    for i, rec in enumerate(property_records[:5]):
        print(f"  Property ID: {rec['property_id']}")
        if i >= 4:  # Show max 5
            break
# Out:
# ✓ Properties upserted: 1007
# ✓ Property records created
#
# Sample property records:
#   Property ID: 12db370f-b11d-46ba-8bed-e6e2a0f03236
#   Property ID: d934fbc4-a0c4-4905-99da-3f4ae1ff906e
#   Property ID: e2bd4e9a-2ef1-4254-a0c7-fc91de8912fc
#   Property ID: f70a0460-0bdc-467f-ac16-7b48acb10b00
#   Property ID: 7c9921e2-35c9-4766-81f6-2a73298d4877

# %% [markdown]
# ## Step 7: Load Pools to Master DB
#
# Upsert pools to master database.

# %%
load_pools_result = upsert_pools(
    transform_new_result['pools_path'],
    property_records
)

print(f"\n✓ Pools upserted: {load_pools_result['pool_count']}")
# Out:
# ✓ Pools upserted: 1007

# %% [markdown]
# ## Step 8: Load Listings to Master DB
#
# Upsert listings to master database.

# %%
load_listings_result = upsert_listings(
    transform_new_result['listings_path'],
    property_records
)

print(f"\n✓ Listings upserted: {load_listings_result['listing_count']}")
# Out:
# ✓ Listings upserted: 1007

# %% [markdown]
# ## Step 9: Update Removed Listings
#
# Mark removed listings as sold in master database.

# %%
update_removed_result = update_removed_listings(transform_removed_result['updates_path'])

print(f"\n✓ Listings marked as removed: {update_removed_result['update_count']}")
# Out:
# ✓ Listings marked as removed: 0

# %% [markdown]
# ## Summary & Verification
#
# Check results in master database.

# %%
from include.db.connections import get_master_db_connection

print("="*60)
print("PIPELINE EXECUTION SUMMARY")
print("="*60)

print(f"\n📊 Extraction:")
print(f"  • New pool listings: {result['row_count']}")
print(f"  • Removed pool listings: {result_removed['row_count']}")

print(f"\n🔍 Matching:")
print(f"  • New listings matched: {match_result['new_matched_count']}")
print(f"  • New listings unmatched: {transform_new_result['property_count']}")
print(f"  • Removed listings matched: {match_result['removed_matched_count']}")

print(f"\n💾 Database Updates:")
print(f"  • Properties upserted: {len(property_records)}")
print(f"  • Pools upserted: {load_pools_result['pool_count']}")
print(f"  • Listings upserted: {load_listings_result['listing_count']}")
print(f"  • Listings marked removed: {update_removed_result['update_count']}")

print(f"\n🗂️  Working directory: {workdir}")

# Verify in database
print("\n" + "="*60)
print("DATABASE VERIFICATION")
print("="*60)

conn = get_master_db_connection()
try:
    with conn.cursor() as cur:
        # Count properties
        cur.execute("SELECT COUNT(*) FROM properties;")
        print(f"\nTotal properties in DB: {cur.fetchone()[0]:,}")
        
        # Count pools
        cur.execute("SELECT COUNT(*) FROM pools;")
        print(f"Total pools in DB: {cur.fetchone()[0]:,}")
        
        # Count listings
        cur.execute("SELECT COUNT(*) FROM listings;")
        total_listings = cur.fetchone()[0]
        print(f"Total listings in DB: {total_listings:,}")
        
        # Count removed listings
        cur.execute("SELECT COUNT(*) FROM listings WHERE is_removed = true;")
        removed_listings = cur.fetchone()[0]
        print(f"Removed listings: {removed_listings:,}")
        print(f"Active listings: {total_listings - removed_listings:,}")
        
finally:
    conn.close()

print("\n" + "="*60)
print("✅ PIPELINE TEST COMPLETE")
print("="*60)
# Out:
# ============================================================
# PIPELINE EXECUTION SUMMARY
# ============================================================
#
# 📊 Extraction:
#   • New pool listings: 1007
#   • Removed pool listings: 196
#
# 🔍 Matching:
#   • New listings matched: 0
#   • New listings unmatched: 1007
#   • Removed listings matched: 0
#
# 💾 Database Updates:
#   • Properties upserted: 1007
#   • Pools upserted: 1007
#   • Listings upserted: 1007
#   • Listings marked removed: 0
#
# 🗂️  Working directory: /tmp/client_data_test_20260128_153428
#
# ============================================================
# DATABASE VERIFICATION
# ============================================================
#
# Total properties in DB: 23,533
# Total pools in DB: 23,443
# Total listings in DB: 1,034
# Removed listings: 13
# Active listings: 1,021
#
# ============================================================
# ✅ PIPELINE TEST COMPLETE
# ============================================================
