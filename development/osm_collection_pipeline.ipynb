# %% [markdown]
# ## OSM Data Collection Pipeline

# %%
import time
import requests
from shapely.geometry import shape, box

# Use a reliable Overpass endpoint
OVERPASS_URL = "https://overpass-api.de/api/interpreter"

def subdivide_bbox(s, w, n, e, side_deg=0.02):
    """
    Split a large bbox into smaller ones ~0.02° per side (~4 km²)
    """
    boxes = []
    lat = s
    while lat < n:
        lon = w
        next_lat = min(lat + side_deg, n)
        while lon < e:
            next_lon = min(lon + side_deg, e)
            boxes.append((lat, lon, next_lat, next_lon))
            lon = next_lon
        lat = next_lat
    return boxes

def make_query(s, w, n, e):
    return f"""
    [out:json][timeout:120];
    (
      node["leisure"="swimming_pool"]({s},{w},{n},{e});
      way["leisure"="swimming_pool"]({s},{w},{n},{e});
      relation["leisure"="swimming_pool"]({s},{w},{n},{e});
      node["swimming_pool"="yes"]({s},{w},{n},{e});
      way["swimming_pool"="yes"]({s},{w},{n},{e});
      relation["swimming_pool"="yes"]({s},{w},{n},{e});
    );
    out center tags;
    """

def request_overpass(s, w, n, e):
    """
    Query Overpass with bbox. If server errors, subdivide tile.
    """
    query = make_query(s, w, n, e)
    try:
        r = requests.post(OVERPASS_URL, data={"data": query}, timeout=180)
    except requests.exceptions.RequestException as err:
        print(f"    !!! Request failed: {err}")
        return []

    if r.status_code == 429:
        print("    !!! Rate limited (429). Sleeping 5s...")
        time.sleep(5)
        return request_overpass(s, w, n, e)

    if r.status_code == 504:
        print("    !!! Gateway Timeout (504). Splitting request...")
        # split further if too big
        mid_lat = (s+n)/2
        mid_lon = (w+e)/2
        return (
            request_overpass(s, w, mid_lat, mid_lon)
            + request_overpass(s, mid_lon, mid_lat, e)
            + request_overpass(mid_lat, w, n, mid_lon)
            + request_overpass(mid_lat, mid_lon, n, e)
        )

    r.raise_for_status()
    # Check if we got valid JSON and elements
    try:
        data = r.json()
        return data.get("elements", [])
    except Exception as e:
        print(f"    !!! Failed to parse JSON response: {e}")
        return []

def extract_pools(elements):
    results = []
    for elt in elements:
        if "lat" in elt and "lon" in elt:
            lat, lon = elt["lat"], elt["lon"]
        elif "center" in elt:
            lat, lon = elt["center"]["lat"], elt["center"]["lon"]
        else:
            continue

        results.append({
            "lat": lat,
            "lon": lon,
            "tags": elt.get("tags", {})
        })
    return results

def get_pools(geojson):
    poly = shape(geojson)
    # Correctly unpack bounds: (minx, miny, maxx, maxy) -> (West, South, East, North)
    w, s, e, n = poly.bounds
    print(f"Polygon bounds: South={s:.4f}, West={w:.4f}, North={n:.4f}, East={e:.4f}")

    tiles = subdivide_bbox(s, w, n, e)
    print(f"Subdivided area into {len(tiles)} tiles.")

    all_pools = []
    seen = set()
    
    # Pre-filter tiles to print accurate progress count
    tiles_to_process = []
    for (ts, tw, tn, te) in tiles:
        tile = box(tw, ts, te, tn)
        if poly.intersects(tile):
            tiles_to_process.append((ts, tw, tn, te))
    
    print(f"Processing {len(tiles_to_process)} tiles intersecting the polygon...")

    for i, (ts, tw, tn, te) in enumerate(tiles_to_process, 1):
        print(f"  [Tile {i}/{len(tiles_to_process)}] Querying bbox ({ts:.4f}, {tw:.4f}, {tn:.4f}, {te:.4f})...")
        
        elements = request_overpass(ts, tw, tn, te)
        pools = extract_pools(elements)
        
        if elements:
            print(f"    -> Found {len(elements)} raw elements, extracted {len(pools)} pools.")
        
        new_count = 0
        for p in pools:
            key = (p["lat"], p["lon"])
            if key not in seen:
                seen.add(key)
                all_pools.append(p)
                new_count += 1
        
        if new_count > 0:
            print(f"    -> Added {new_count} new unique pools.")

    return all_pools

# %%
sample_polygon = [
    [-81.01262, 43.48260],
    [-81.08653, 43.35806],
    [-80.99489, 43.23542],
    [-80.60763, 43.25911],
    [-80.45686, 43.38814],
    [-80.78204, 43.46758],
    [-81.01262, 43.48260],
]

sample_geojson = {"type":"Polygon","coordinates":[sample_polygon]}

if __name__ == "__main__":
    pools = get_pools(sample_geojson)
    print(f"Found {len(pools)} pools")
    for p in pools:
        print(p)
# Out:
# Polygon bounds: South=43.2354, West=-81.0865, North=43.4826, East=-80.4569
# Subdivided area into 416 tiles.
# Processing 311 tiles intersecting the polygon...
#   [Tile 1/311] Querying bbox (43.2354, -81.0265, 43.2554, -81.0065)...
#   [Tile 2/311] Querying bbox (43.2354, -81.0065, 43.2554, -80.9865)...
#   [Tile 3/311] Querying bbox (43.2354, -80.9865, 43.2554, -80.9665)...
#   [Tile 4/311] Querying bbox (43.2354, -80.9665, 43.2554, -80.9465)...
#   [Tile 5/311] Querying bbox (43.2354, -80.9465, 43.2554, -80.9265)...
#   [Tile 6/311] Querying bbox (43.2354, -80.9265, 43.2554, -80.9065)...
#   [Tile 7/311] Querying bbox (43.2354, -80.9065, 43.2554, -80.8865)...
#   [Tile 8/311] Querying bbox (43.2354, -80.8865, 43.2554, -80.8665)...
#   [Tile 9/311] Querying bbox (43.2354, -80.8665, 43.2554, -80.8465)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 10/311] Querying bbox (43.2354, -80.8465, 43.2554, -80.8265)...
#   [Tile 11/311] Querying bbox (43.2354, -80.8265, 43.2554, -80.8065)...
#   [Tile 12/311] Querying bbox (43.2354, -80.8065, 43.2554, -80.7865)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 13/311] Querying bbox (43.2354, -80.7865, 43.2554, -80.7665)...
#   [Tile 14/311] Querying bbox (43.2354, -80.7665, 43.2554, -80.7465)...
#   [Tile 15/311] Querying bbox (43.2354, -80.7465, 43.2554, -80.7265)...
#   [Tile 16/311] Querying bbox (43.2354, -80.7265, 43.2554, -80.7065)...
#   [Tile 17/311] Querying bbox (43.2354, -80.7065, 43.2554, -80.6865)...
#   [Tile 18/311] Querying bbox (43.2354, -80.6865, 43.2554, -80.6665)...
#   [Tile 19/311] Querying bbox (43.2554, -81.0265, 43.2754, -81.0065)...
#   [Tile 20/311] Querying bbox (43.2554, -81.0065, 43.2754, -80.9865)...
#   [Tile 21/311] Querying bbox (43.2554, -80.9865, 43.2754, -80.9665)...
#   [Tile 22/311] Querying bbox (43.2554, -80.9665, 43.2754, -80.9465)...
#   [Tile 23/311] Querying bbox (43.2554, -80.9465, 43.2754, -80.9265)...
#   [Tile 24/311] Querying bbox (43.2554, -80.9265, 43.2754, -80.9065)...
#   [Tile 25/311] Querying bbox (43.2554, -80.9065, 43.2754, -80.8865)...
#   [Tile 26/311] Querying bbox (43.2554, -80.8865, 43.2754, -80.8665)...
#   [Tile 27/311] Querying bbox (43.2554, -80.8665, 43.2754, -80.8465)...
#   [Tile 28/311] Querying bbox (43.2554, -80.8465, 43.2754, -80.8265)...
#   [Tile 29/311] Querying bbox (43.2554, -80.8265, 43.2754, -80.8065)...
#   [Tile 30/311] Querying bbox (43.2554, -80.8065, 43.2754, -80.7865)...
#   [Tile 31/311] Querying bbox (43.2554, -80.7865, 43.2754, -80.7665)...
#   [Tile 32/311] Querying bbox (43.2554, -80.7665, 43.2754, -80.7465)...
#     !!! Gateway Timeout (504). Splitting request...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 33/311] Querying bbox (43.2554, -80.7465, 43.2754, -80.7265)...
#   [Tile 34/311] Querying bbox (43.2554, -80.7265, 43.2754, -80.7065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 35/311] Querying bbox (43.2554, -80.7065, 43.2754, -80.6865)...
#   [Tile 36/311] Querying bbox (43.2554, -80.6865, 43.2754, -80.6665)...
#   [Tile 37/311] Querying bbox (43.2554, -80.6665, 43.2754, -80.6465)...
#   [Tile 38/311] Querying bbox (43.2554, -80.6465, 43.2754, -80.6265)...
#   [Tile 39/311] Querying bbox (43.2554, -80.6265, 43.2754, -80.6065)...
#   [Tile 40/311] Querying bbox (43.2554, -80.6065, 43.2754, -80.5865)...
#   [Tile 41/311] Querying bbox (43.2754, -81.0465, 43.2954, -81.0265)...
#   [Tile 42/311] Querying bbox (43.2754, -81.0265, 43.2954, -81.0065)...
#   [Tile 43/311] Querying bbox (43.2754, -81.0065, 43.2954, -80.9865)...
#   [Tile 44/311] Querying bbox (43.2754, -80.9865, 43.2954, -80.9665)...
#   [Tile 45/311] Querying bbox (43.2754, -80.9665, 43.2954, -80.9465)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 46/311] Querying bbox (43.2754, -80.9465, 43.2954, -80.9265)...
#   [Tile 47/311] Querying bbox (43.2754, -80.9265, 43.2954, -80.9065)...
#   [Tile 48/311] Querying bbox (43.2754, -80.9065, 43.2954, -80.8865)...
#   [Tile 49/311] Querying bbox (43.2754, -80.8865, 43.2954, -80.8665)...
#   [Tile 50/311] Querying bbox (43.2754, -80.8665, 43.2954, -80.8465)...
#   [Tile 51/311] Querying bbox (43.2754, -80.8465, 43.2954, -80.8265)...
#   [Tile 52/311] Querying bbox (43.2754, -80.8265, 43.2954, -80.8065)...
#   [Tile 53/311] Querying bbox (43.2754, -80.8065, 43.2954, -80.7865)...
#   [Tile 54/311] Querying bbox (43.2754, -80.7865, 43.2954, -80.7665)...
#   [Tile 55/311] Querying bbox (43.2754, -80.7665, 43.2954, -80.7465)...
#   [Tile 56/311] Querying bbox (43.2754, -80.7465, 43.2954, -80.7265)...
#   [Tile 57/311] Querying bbox (43.2754, -80.7265, 43.2954, -80.7065)...
#   [Tile 58/311] Querying bbox (43.2754, -80.7065, 43.2954, -80.6865)...
#   [Tile 59/311] Querying bbox (43.2754, -80.6865, 43.2954, -80.6665)...
#   [Tile 60/311] Querying bbox (43.2754, -80.6665, 43.2954, -80.6465)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 61/311] Querying bbox (43.2754, -80.6465, 43.2954, -80.6265)...
#   [Tile 62/311] Querying bbox (43.2754, -80.6265, 43.2954, -80.6065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 63/311] Querying bbox (43.2754, -80.6065, 43.2954, -80.5865)...
#   [Tile 64/311] Querying bbox (43.2754, -80.5865, 43.2954, -80.5665)...
#   [Tile 65/311] Querying bbox (43.2754, -80.5665, 43.2954, -80.5465)...
#   [Tile 66/311] Querying bbox (43.2954, -81.0665, 43.3154, -81.0465)...
#   [Tile 67/311] Querying bbox (43.2954, -81.0465, 43.3154, -81.0265)...
#   [Tile 68/311] Querying bbox (43.2954, -81.0265, 43.3154, -81.0065)...
#   [Tile 69/311] Querying bbox (43.2954, -81.0065, 43.3154, -80.9865)...
#   [Tile 70/311] Querying bbox (43.2954, -80.9865, 43.3154, -80.9665)...
#   [Tile 71/311] Querying bbox (43.2954, -80.9665, 43.3154, -80.9465)...
#   [Tile 72/311] Querying bbox (43.2954, -80.9465, 43.3154, -80.9265)...
#   [Tile 73/311] Querying bbox (43.2954, -80.9265, 43.3154, -80.9065)...
#   [Tile 74/311] Querying bbox (43.2954, -80.9065, 43.3154, -80.8865)...
#   [Tile 75/311] Querying bbox (43.2954, -80.8865, 43.3154, -80.8665)...
#   [Tile 76/311] Querying bbox (43.2954, -80.8665, 43.3154, -80.8465)...
#   [Tile 77/311] Querying bbox (43.2954, -80.8465, 43.3154, -80.8265)...
#   [Tile 78/311] Querying bbox (43.2954, -80.8265, 43.3154, -80.8065)...
#   [Tile 79/311] Querying bbox (43.2954, -80.8065, 43.3154, -80.7865)...
#   [Tile 80/311] Querying bbox (43.2954, -80.7865, 43.3154, -80.7665)...
#   [Tile 81/311] Querying bbox (43.2954, -80.7665, 43.3154, -80.7465)...
#   [Tile 82/311] Querying bbox (43.2954, -80.7465, 43.3154, -80.7265)...
#   [Tile 83/311] Querying bbox (43.2954, -80.7265, 43.3154, -80.7065)...
#   [Tile 84/311] Querying bbox (43.2954, -80.7065, 43.3154, -80.6865)...
#   [Tile 85/311] Querying bbox (43.2954, -80.6865, 43.3154, -80.6665)...
#   [Tile 86/311] Querying bbox (43.2954, -80.6665, 43.3154, -80.6465)...
#   [Tile 87/311] Querying bbox (43.2954, -80.6465, 43.3154, -80.6265)...
#   [Tile 88/311] Querying bbox (43.2954, -80.6265, 43.3154, -80.6065)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 89/311] Querying bbox (43.2954, -80.6065, 43.3154, -80.5865)...
#   [Tile 90/311] Querying bbox (43.2954, -80.5865, 43.3154, -80.5665)...
#   [Tile 91/311] Querying bbox (43.2954, -80.5665, 43.3154, -80.5465)...
#   [Tile 92/311] Querying bbox (43.2954, -80.5465, 43.3154, -80.5265)...
#   [Tile 93/311] Querying bbox (43.3154, -81.0865, 43.3354, -81.0665)...
#   [Tile 94/311] Querying bbox (43.3154, -81.0665, 43.3354, -81.0465)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 95/311] Querying bbox (43.3154, -81.0465, 43.3354, -81.0265)...
#   [Tile 96/311] Querying bbox (43.3154, -81.0265, 43.3354, -81.0065)...
#   [Tile 97/311] Querying bbox (43.3154, -81.0065, 43.3354, -80.9865)...
#   [Tile 98/311] Querying bbox (43.3154, -80.9865, 43.3354, -80.9665)...
#   [Tile 99/311] Querying bbox (43.3154, -80.9665, 43.3354, -80.9465)...
#   [Tile 100/311] Querying bbox (43.3154, -80.9465, 43.3354, -80.9265)...
#   [Tile 101/311] Querying bbox (43.3154, -80.9265, 43.3354, -80.9065)...
#   [Tile 102/311] Querying bbox (43.3154, -80.9065, 43.3354, -80.8865)...
#   [Tile 103/311] Querying bbox (43.3154, -80.8865, 43.3354, -80.8665)...
#   [Tile 104/311] Querying bbox (43.3154, -80.8665, 43.3354, -80.8465)...
#   [Tile 105/311] Querying bbox (43.3154, -80.8465, 43.3354, -80.8265)...
#   [Tile 106/311] Querying bbox (43.3154, -80.8265, 43.3354, -80.8065)...
#     -> Found 2 raw elements, extracted 2 pools.
#     -> Added 2 new unique pools.
#   [Tile 107/311] Querying bbox (43.3154, -80.8065, 43.3354, -80.7865)...
#   [Tile 108/311] Querying bbox (43.3154, -80.7865, 43.3354, -80.7665)...
#   [Tile 109/311] Querying bbox (43.3154, -80.7665, 43.3354, -80.7465)...
#   [Tile 110/311] Querying bbox (43.3154, -80.7465, 43.3354, -80.7265)...
#   [Tile 111/311] Querying bbox (43.3154, -80.7265, 43.3354, -80.7065)...
#   [Tile 112/311] Querying bbox (43.3154, -80.7065, 43.3354, -80.6865)...
#   [Tile 113/311] Querying bbox (43.3154, -80.6865, 43.3354, -80.6665)...
#   [Tile 114/311] Querying bbox (43.3154, -80.6665, 43.3354, -80.6465)...
#   [Tile 115/311] Querying bbox (43.3154, -80.6465, 43.3354, -80.6265)...
#   [Tile 116/311] Querying bbox (43.3154, -80.6265, 43.3354, -80.6065)...
#   [Tile 117/311] Querying bbox (43.3154, -80.6065, 43.3354, -80.5865)...
#   [Tile 118/311] Querying bbox (43.3154, -80.5865, 43.3354, -80.5665)...
#   [Tile 119/311] Querying bbox (43.3154, -80.5665, 43.3354, -80.5465)...
#   [Tile 120/311] Querying bbox (43.3154, -80.5465, 43.3354, -80.5265)...
#   [Tile 121/311] Querying bbox (43.3154, -80.5265, 43.3354, -80.5065)...
#   [Tile 122/311] Querying bbox (43.3354, -81.0865, 43.3554, -81.0665)...
#   [Tile 123/311] Querying bbox (43.3354, -81.0665, 43.3554, -81.0465)...
#   [Tile 124/311] Querying bbox (43.3354, -81.0465, 43.3554, -81.0265)...
#   [Tile 125/311] Querying bbox (43.3354, -81.0265, 43.3554, -81.0065)...
#   [Tile 126/311] Querying bbox (43.3354, -81.0065, 43.3554, -80.9865)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 127/311] Querying bbox (43.3354, -80.9865, 43.3554, -80.9665)...
#   [Tile 128/311] Querying bbox (43.3354, -80.9665, 43.3554, -80.9465)...
#   [Tile 129/311] Querying bbox (43.3354, -80.9465, 43.3554, -80.9265)...
#   [Tile 130/311] Querying bbox (43.3354, -80.9265, 43.3554, -80.9065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 131/311] Querying bbox (43.3354, -80.9065, 43.3554, -80.8865)...
#   [Tile 132/311] Querying bbox (43.3354, -80.8865, 43.3554, -80.8665)...
#   [Tile 133/311] Querying bbox (43.3354, -80.8665, 43.3554, -80.8465)...
#   [Tile 134/311] Querying bbox (43.3354, -80.8465, 43.3554, -80.8265)...
#   [Tile 135/311] Querying bbox (43.3354, -80.8265, 43.3554, -80.8065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 136/311] Querying bbox (43.3354, -80.8065, 43.3554, -80.7865)...
#   [Tile 137/311] Querying bbox (43.3354, -80.7865, 43.3554, -80.7665)...
#   [Tile 138/311] Querying bbox (43.3354, -80.7665, 43.3554, -80.7465)...
#   [Tile 139/311] Querying bbox (43.3354, -80.7465, 43.3554, -80.7265)...
#   [Tile 140/311] Querying bbox (43.3354, -80.7265, 43.3554, -80.7065)...
#   [Tile 141/311] Querying bbox (43.3354, -80.7065, 43.3554, -80.6865)...
#   [Tile 142/311] Querying bbox (43.3354, -80.6865, 43.3554, -80.6665)...
#   [Tile 143/311] Querying bbox (43.3354, -80.6665, 43.3554, -80.6465)...
#   [Tile 144/311] Querying bbox (43.3354, -80.6465, 43.3554, -80.6265)...
#   [Tile 145/311] Querying bbox (43.3354, -80.6265, 43.3554, -80.6065)...
#   [Tile 146/311] Querying bbox (43.3354, -80.6065, 43.3554, -80.5865)...
#   [Tile 147/311] Querying bbox (43.3354, -80.5865, 43.3554, -80.5665)...
#   [Tile 148/311] Querying bbox (43.3354, -80.5665, 43.3554, -80.5465)...
#   [Tile 149/311] Querying bbox (43.3354, -80.5465, 43.3554, -80.5265)...
#   [Tile 150/311] Querying bbox (43.3354, -80.5265, 43.3554, -80.5065)...
#   [Tile 151/311] Querying bbox (43.3354, -80.5065, 43.3554, -80.4865)...
#   [Tile 152/311] Querying bbox (43.3554, -81.0865, 43.3754, -81.0665)...
#   [Tile 153/311] Querying bbox (43.3554, -81.0665, 43.3754, -81.0465)...
#   [Tile 154/311] Querying bbox (43.3554, -81.0465, 43.3754, -81.0265)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 155/311] Querying bbox (43.3554, -81.0265, 43.3754, -81.0065)...
#   [Tile 156/311] Querying bbox (43.3554, -81.0065, 43.3754, -80.9865)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 157/311] Querying bbox (43.3554, -80.9865, 43.3754, -80.9665)...
#     -> Found 3 raw elements, extracted 3 pools.
#     -> Added 3 new unique pools.
#   [Tile 158/311] Querying bbox (43.3554, -80.9665, 43.3754, -80.9465)...
#   [Tile 159/311] Querying bbox (43.3554, -80.9465, 43.3754, -80.9265)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 160/311] Querying bbox (43.3554, -80.9265, 43.3754, -80.9065)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 161/311] Querying bbox (43.3554, -80.9065, 43.3754, -80.8865)...
#   [Tile 162/311] Querying bbox (43.3554, -80.8865, 43.3754, -80.8665)...
#   [Tile 163/311] Querying bbox (43.3554, -80.8665, 43.3754, -80.8465)...
#     !!! Rate limited (429). Sleeping 5s...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 164/311] Querying bbox (43.3554, -80.8465, 43.3754, -80.8265)...
#   [Tile 165/311] Querying bbox (43.3554, -80.8265, 43.3754, -80.8065)...
#   [Tile 166/311] Querying bbox (43.3554, -80.8065, 43.3754, -80.7865)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 167/311] Querying bbox (43.3554, -80.7865, 43.3754, -80.7665)...
#   [Tile 168/311] Querying bbox (43.3554, -80.7665, 43.3754, -80.7465)...
#   [Tile 169/311] Querying bbox (43.3554, -80.7465, 43.3754, -80.7265)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 170/311] Querying bbox (43.3554, -80.7265, 43.3754, -80.7065)...
#   [Tile 171/311] Querying bbox (43.3554, -80.7065, 43.3754, -80.6865)...
#   [Tile 172/311] Querying bbox (43.3554, -80.6865, 43.3754, -80.6665)...
#   [Tile 173/311] Querying bbox (43.3554, -80.6665, 43.3754, -80.6465)...
#   [Tile 174/311] Querying bbox (43.3554, -80.6465, 43.3754, -80.6265)...
#   [Tile 175/311] Querying bbox (43.3554, -80.6265, 43.3754, -80.6065)...
#   [Tile 176/311] Querying bbox (43.3554, -80.6065, 43.3754, -80.5865)...
#   [Tile 177/311] Querying bbox (43.3554, -80.5865, 43.3754, -80.5665)...
#   [Tile 178/311] Querying bbox (43.3554, -80.5665, 43.3754, -80.5465)...
#   [Tile 179/311] Querying bbox (43.3554, -80.5465, 43.3754, -80.5265)...
#   [Tile 180/311] Querying bbox (43.3554, -80.5265, 43.3754, -80.5065)...
#   [Tile 181/311] Querying bbox (43.3554, -80.5065, 43.3754, -80.4865)...
#   [Tile 182/311] Querying bbox (43.3554, -80.4865, 43.3754, -80.4665)...
#   [Tile 183/311] Querying bbox (43.3754, -81.0865, 43.3954, -81.0665)...
#   [Tile 184/311] Querying bbox (43.3754, -81.0665, 43.3954, -81.0465)...
#   [Tile 185/311] Querying bbox (43.3754, -81.0465, 43.3954, -81.0265)...
#   [Tile 186/311] Querying bbox (43.3754, -81.0265, 43.3954, -81.0065)...
#   [Tile 187/311] Querying bbox (43.3754, -81.0065, 43.3954, -80.9865)...
#   [Tile 188/311] Querying bbox (43.3754, -80.9865, 43.3954, -80.9665)...
#   [Tile 189/311] Querying bbox (43.3754, -80.9665, 43.3954, -80.9465)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 190/311] Querying bbox (43.3754, -80.9465, 43.3954, -80.9265)...
#   [Tile 191/311] Querying bbox (43.3754, -80.9265, 43.3954, -80.9065)...
#   [Tile 192/311] Querying bbox (43.3754, -80.9065, 43.3954, -80.8865)...
#   [Tile 193/311] Querying bbox (43.3754, -80.8865, 43.3954, -80.8665)...
#   [Tile 194/311] Querying bbox (43.3754, -80.8665, 43.3954, -80.8465)...
#   [Tile 195/311] Querying bbox (43.3754, -80.8465, 43.3954, -80.8265)...
#   [Tile 196/311] Querying bbox (43.3754, -80.8265, 43.3954, -80.8065)...
#   [Tile 197/311] Querying bbox (43.3754, -80.8065, 43.3954, -80.7865)...
#   [Tile 198/311] Querying bbox (43.3754, -80.7865, 43.3954, -80.7665)...
#   [Tile 199/311] Querying bbox (43.3754, -80.7665, 43.3954, -80.7465)...
#   [Tile 200/311] Querying bbox (43.3754, -80.7465, 43.3954, -80.7265)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 201/311] Querying bbox (43.3754, -80.7265, 43.3954, -80.7065)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 202/311] Querying bbox (43.3754, -80.7065, 43.3954, -80.6865)...
#     -> Found 1 raw elements, extracted 1 pools.
#   [Tile 203/311] Querying bbox (43.3754, -80.6865, 43.3954, -80.6665)...
#   [Tile 204/311] Querying bbox (43.3754, -80.6665, 43.3954, -80.6465)...
#   [Tile 205/311] Querying bbox (43.3754, -80.6465, 43.3954, -80.6265)...
#   [Tile 206/311] Querying bbox (43.3754, -80.6265, 43.3954, -80.6065)...
#   [Tile 207/311] Querying bbox (43.3754, -80.6065, 43.3954, -80.5865)...
#   [Tile 208/311] Querying bbox (43.3754, -80.5865, 43.3954, -80.5665)...
#   [Tile 209/311] Querying bbox (43.3754, -80.5665, 43.3954, -80.5465)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 210/311] Querying bbox (43.3754, -80.5465, 43.3954, -80.5265)...
#     -> Found 17 raw elements, extracted 17 pools.
#     -> Added 17 new unique pools.
#   [Tile 211/311] Querying bbox (43.3754, -80.5265, 43.3954, -80.5065)...
#   [Tile 212/311] Querying bbox (43.3754, -80.5065, 43.3954, -80.4865)...
#     -> Found 2 raw elements, extracted 2 pools.
#     -> Added 2 new unique pools.
#   [Tile 213/311] Querying bbox (43.3754, -80.4865, 43.3954, -80.4665)...
#   [Tile 214/311] Querying bbox (43.3754, -80.4665, 43.3954, -80.4569)...
#   [Tile 215/311] Querying bbox (43.3954, -81.0665, 43.4154, -81.0465)...
#   [Tile 216/311] Querying bbox (43.3954, -81.0465, 43.4154, -81.0265)...
#   [Tile 217/311] Querying bbox (43.3954, -81.0265, 43.4154, -81.0065)...
#   [Tile 218/311] Querying bbox (43.3954, -81.0065, 43.4154, -80.9865)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 219/311] Querying bbox (43.3954, -80.9865, 43.4154, -80.9665)...
#   [Tile 220/311] Querying bbox (43.3954, -80.9665, 43.4154, -80.9465)...
#   [Tile 221/311] Querying bbox (43.3954, -80.9465, 43.4154, -80.9265)...
#   [Tile 222/311] Querying bbox (43.3954, -80.9265, 43.4154, -80.9065)...
#   [Tile 223/311] Querying bbox (43.3954, -80.9065, 43.4154, -80.8865)...
#   [Tile 224/311] Querying bbox (43.3954, -80.8865, 43.4154, -80.8665)...
#   [Tile 225/311] Querying bbox (43.3954, -80.8665, 43.4154, -80.8465)...
#   [Tile 226/311] Querying bbox (43.3954, -80.8465, 43.4154, -80.8265)...
#   [Tile 227/311] Querying bbox (43.3954, -80.8265, 43.4154, -80.8065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 228/311] Querying bbox (43.3954, -80.8065, 43.4154, -80.7865)...
#   [Tile 229/311] Querying bbox (43.3954, -80.7865, 43.4154, -80.7665)...
#   [Tile 230/311] Querying bbox (43.3954, -80.7665, 43.4154, -80.7465)...
#   [Tile 231/311] Querying bbox (43.3954, -80.7465, 43.4154, -80.7265)...
#   [Tile 232/311] Querying bbox (43.3954, -80.7265, 43.4154, -80.7065)...
#     -> Found 1 raw elements, extracted 1 pools.
#     -> Added 1 new unique pools.
#   [Tile 233/311] Querying bbox (43.3954, -80.7065, 43.4154, -80.6865)...
#   [Tile 234/311] Querying bbox (43.3954, -80.6865, 43.4154, -80.6665)...
#   [Tile 235/311] Querying bbox (43.3954, -80.6665, 43.4154, -80.6465)...
#   [Tile 236/311] Querying bbox (43.3954, -80.6465, 43.4154, -80.6265)...
#   [Tile 237/311] Querying bbox (43.3954, -80.6265, 43.4154, -80.6065)...
#   [Tile 238/311] Querying bbox (43.3954, -80.6065, 43.4154, -80.5865)...
#   [Tile 239/311] Querying bbox (43.3954, -80.5865, 43.4154, -80.5665)...
#   [Tile 240/311] Querying bbox (43.3954, -80.5665, 43.4154, -80.5465)...
#     -> Found 6 raw elements, extracted 6 pools.
#     -> Added 6 new unique pools.
#   [Tile 241/311] Querying bbox (43.3954, -80.5465, 43.4154, -80.5265)...
#     -> Found 72 raw elements, extracted 72 pools.
#     -> Added 68 new unique pools.
#   [Tile 242/311] Querying bbox (43.3954, -80.5265, 43.4154, -80.5065)...
#   [Tile 243/311] Querying bbox (43.3954, -80.5065, 43.4154, -80.4865)...
#     -> Found 9 raw elements, extracted 9 pools.
#     -> Added 9 new unique pools.
#   [Tile 244/311] Querying bbox (43.4154, -81.0665, 43.4354, -81.0465)...
#   [Tile 245/311] Querying bbox (43.4154, -81.0465, 43.4354, -81.0265)...
#   [Tile 246/311] Querying bbox (43.4154, -81.0265, 43.4354, -81.0065)...
#   [Tile 247/311] Querying bbox (43.4154, -81.0065, 43.4354, -80.9865)...
#   [Tile 248/311] Querying bbox (43.4154, -80.9865, 43.4354, -80.9665)...
#   [Tile 249/311] Querying bbox (43.4154, -80.9665, 43.4354, -80.9465)...
#   [Tile 250/311] Querying bbox (43.4154, -80.9465, 43.4354, -80.9265)...
#   [Tile 251/311] Querying bbox (43.4154, -80.9265, 43.4354, -80.9065)...
#   [Tile 252/311] Querying bbox (43.4154, -80.9065, 43.4354, -80.8865)...
#   [Tile 253/311] Querying bbox (43.4154, -80.8865, 43.4354, -80.8665)...
#   [Tile 254/311] Querying bbox (43.4154, -80.8665, 43.4354, -80.8465)...
#   [Tile 255/311] Querying bbox (43.4154, -80.8465, 43.4354, -80.8265)...
#   [Tile 256/311] Querying bbox (43.4154, -80.8265, 43.4354, -80.8065)...
#   [Tile 257/311] Querying bbox (43.4154, -80.8065, 43.4354, -80.7865)...
#   [Tile 258/311] Querying bbox (43.4154, -80.7865, 43.4354, -80.7665)...
#   [Tile 259/311] Querying bbox (43.4154, -80.7665, 43.4354, -80.7465)...
#   [Tile 260/311] Querying bbox (43.4154, -80.7465, 43.4354, -80.7265)...
#   [Tile 261/311] Querying bbox (43.4154, -80.7265, 43.4354, -80.7065)...
#   [Tile 262/311] Querying bbox (43.4154, -80.7065, 43.4354, -80.6865)...
#   [Tile 263/311] Querying bbox (43.4154, -80.6865, 43.4354, -80.6665)...
#   [Tile 264/311] Querying bbox (43.4154, -80.6665, 43.4354, -80.6465)...
#   [Tile 265/311] Querying bbox (43.4154, -80.6465, 43.4354, -80.6265)...
#   [Tile 266/311] Querying bbox (43.4154, -80.6265, 43.4354, -80.6065)...
#   [Tile 267/311] Querying bbox (43.4154, -80.6065, 43.4354, -80.5865)...
#   [Tile 268/311] Querying bbox (43.4154, -80.5865, 43.4354, -80.5665)...
#   [Tile 269/311] Querying bbox (43.4354, -81.0465, 43.4554, -81.0265)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 270/311] Querying bbox (43.4354, -81.0265, 43.4554, -81.0065)...
#   [Tile 271/311] Querying bbox (43.4354, -81.0065, 43.4554, -80.9865)...
#   [Tile 272/311] Querying bbox (43.4354, -80.9865, 43.4554, -80.9665)...
#     !!! Rate limited (429). Sleeping 5s...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 273/311] Querying bbox (43.4354, -80.9665, 43.4554, -80.9465)...
#   [Tile 274/311] Querying bbox (43.4354, -80.9465, 43.4554, -80.9265)...
#   [Tile 275/311] Querying bbox (43.4354, -80.9265, 43.4554, -80.9065)...
#   [Tile 276/311] Querying bbox (43.4354, -80.9065, 43.4554, -80.8865)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 277/311] Querying bbox (43.4354, -80.8865, 43.4554, -80.8665)...
#   [Tile 278/311] Querying bbox (43.4354, -80.8665, 43.4554, -80.8465)...
#   [Tile 279/311] Querying bbox (43.4354, -80.8465, 43.4554, -80.8265)...
#   [Tile 280/311] Querying bbox (43.4354, -80.8265, 43.4554, -80.8065)...
#   [Tile 281/311] Querying bbox (43.4354, -80.8065, 43.4554, -80.7865)...
#   [Tile 282/311] Querying bbox (43.4354, -80.7865, 43.4554, -80.7665)...
#   [Tile 283/311] Querying bbox (43.4354, -80.7665, 43.4554, -80.7465)...
#   [Tile 284/311] Querying bbox (43.4354, -80.7465, 43.4554, -80.7265)...
#   [Tile 285/311] Querying bbox (43.4354, -80.7265, 43.4554, -80.7065)...
#   [Tile 286/311] Querying bbox (43.4354, -80.7065, 43.4554, -80.6865)...
#   [Tile 287/311] Querying bbox (43.4354, -80.6865, 43.4554, -80.6665)...
#   [Tile 288/311] Querying bbox (43.4354, -80.6665, 43.4554, -80.6465)...
#   [Tile 289/311] Querying bbox (43.4554, -81.0465, 43.4754, -81.0265)...
#   [Tile 290/311] Querying bbox (43.4554, -81.0265, 43.4754, -81.0065)...
#   [Tile 291/311] Querying bbox (43.4554, -81.0065, 43.4754, -80.9865)...
#   [Tile 292/311] Querying bbox (43.4554, -80.9865, 43.4754, -80.9665)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 293/311] Querying bbox (43.4554, -80.9665, 43.4754, -80.9465)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 294/311] Querying bbox (43.4554, -80.9465, 43.4754, -80.9265)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 295/311] Querying bbox (43.4554, -80.9265, 43.4754, -80.9065)...
#   [Tile 296/311] Querying bbox (43.4554, -80.9065, 43.4754, -80.8865)...
#   [Tile 297/311] Querying bbox (43.4554, -80.8865, 43.4754, -80.8665)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 298/311] Querying bbox (43.4554, -80.8665, 43.4754, -80.8465)...
#   [Tile 299/311] Querying bbox (43.4554, -80.8465, 43.4754, -80.8265)...
#   [Tile 300/311] Querying bbox (43.4554, -80.8265, 43.4754, -80.8065)...
#     !!! Rate limited (429). Sleeping 5s...
#   [Tile 301/311] Querying bbox (43.4554, -80.8065, 43.4754, -80.7865)...
#     !!! Gateway Timeout (504). Splitting request...
#   [Tile 302/311] Querying bbox (43.4554, -80.7865, 43.4754, -80.7665)...
#   [Tile 303/311] Querying bbox (43.4554, -80.7665, 43.4754, -80.7465)...
#   [Tile 304/311] Querying bbox (43.4554, -80.7465, 43.4754, -80.7265)...
#   [Tile 305/311] Querying bbox (43.4754, -81.0265, 43.4826, -81.0065)...
#   [Tile 306/311] Querying bbox (43.4754, -81.0065, 43.4826, -80.9865)...
#   [Tile 307/311] Querying bbox (43.4754, -80.9865, 43.4826, -80.9665)...
#   [Tile 308/311] Querying bbox (43.4754, -80.9665, 43.4826, -80.9465)...
#   [Tile 309/311] Querying bbox (43.4754, -80.9465, 43.4826, -80.9265)...
#   [Tile 310/311] Querying bbox (43.4754, -80.9265, 43.4826, -80.9065)...
#   [Tile 311/311] Querying bbox (43.4754, -80.9065, 43.4826, -80.8865)...
# Found 117 pools
# {'lat': 43.31281, 'lon': -80.6119001, 'tags': {'access': 'private', 'building': 'yes', 'leisure': 'swimming_pool'}}
# {'lat': 43.3292184, 'lon': -80.8092907, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3289124, 'lon': -80.8079521, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3681181, 'lon': -81.0010002, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3707635, 'lon': -80.9758888, 'tags': {'leisure': 'swimming_pool', 'natural': 'water'}}
# {'lat': 43.3728997, 'lon': -80.9842785, 'tags': {'access': 'yes', 'leisure': 'swimming_pool', 'location': 'outdoor', 'swimming_pool': 'kids'}}
# {'lat': 43.3727845, 'lon': -80.984572, 'tags': {'access': 'yes', 'leisure': 'swimming_pool', 'location': 'outdoor'}}
# {'lat': 43.3713415, 'lon': -80.9333756, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3707833, 'lon': -80.9132723, 'tags': {'leisure': 'swimming_pool', 'sport': 'swimming'}}
# {'lat': 43.3744906, 'lon': -80.7281767, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3884007, 'lon': -80.9623719, 'tags': {'access': 'private', 'covered': 'no', 'leisure': 'swimming_pool'}}
# {'lat': 43.3862683, 'lon': -80.7288056, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3779191, 'lon': -80.7065542, 'tags': {'access': 'private', 'leisure': 'swimming_pool', 'location': 'outdoor'}}
# {'lat': 43.3938834, 'lon': -80.5467198, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3953808, 'lon': -80.5398604, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3953094, 'lon': -80.540567, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3953935, 'lon': -80.5404149, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.395396, 'lon': -80.5432584, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.394908, 'lon': -80.5435899, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3944276, 'lon': -80.5429407, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3949832, 'lon': -80.5422607, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3952342, 'lon': -80.541522, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3946361, 'lon': -80.5434417, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3912795, 'lon': -80.54501, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3948266, 'lon': -80.5450344, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3940292, 'lon': -80.544746, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.393726, 'lon': -80.5456151, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.393085, 'lon': -80.5464191, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3954185, 'lon': -80.5452959, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3924602, 'lon': -80.5291178, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3924352, 'lon': -80.528237, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3862535, 'lon': -80.4977499, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.3864028, 'lon': -80.4968296, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4049602, 'lon': -80.7248238, 'tags': {'covered': 'no', 'leisure': 'swimming_pool', 'sport': 'swimming'}}
# {'lat': 43.3986874, 'lon': -80.5470837, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3990485, 'lon': -80.5473228, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4012943, 'lon': -80.5481653, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4020744, 'lon': -80.5469479, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3969312, 'lon': -80.5479354, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.397346, 'lon': -80.547077, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3970375, 'lon': -80.5370349, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3977601, 'lon': -80.5362861, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3987526, 'lon': -80.5390873, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3983405, 'lon': -80.5369303, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3967914, 'lon': -80.5379085, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.396605, 'lon': -80.5390943, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3986034, 'lon': -80.5401394, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3978862, 'lon': -80.53843, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3979502, 'lon': -80.5381699, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3975263, 'lon': -80.5388541, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3972877, 'lon': -80.5403293, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3972445, 'lon': -80.5416838, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3975868, 'lon': -80.5417215, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.398066, 'lon': -80.541579, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3983858, 'lon': -80.5422368, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3978564, 'lon': -80.5429373, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3973671, 'lon': -80.5429196, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.396411, 'lon': -80.5406201, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3956506, 'lon': -80.5395855, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3977401, 'lon': -80.53795, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3964919, 'lon': -80.5412644, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3960698, 'lon': -80.5409368, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3960065, 'lon': -80.540606, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3957356, 'lon': -80.5425791, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3963848, 'lon': -80.5417351, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3961692, 'lon': -80.5427133, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3959605, 'lon': -80.5429948, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.395853, 'lon': -80.5432427, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3966323, 'lon': -80.5444449, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3967205, 'lon': -80.5438956, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3994792, 'lon': -80.5397096, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3995351, 'lon': -80.5411619, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4001611, 'lon': -80.5407842, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3992112, 'lon': -80.5422131, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4013578, 'lon': -80.5403041, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.401418, 'lon': -80.5401699, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4017609, 'lon': -80.5409739, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4021192, 'lon': -80.5410531, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4008825, 'lon': -80.5414052, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4004568, 'lon': -80.5402837, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.400569, 'lon': -80.5435178, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4002599, 'lon': -80.5444557, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4000379, 'lon': -80.5453772, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4000656, 'lon': -80.5430413, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3999936, 'lon': -80.5435833, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4001166, 'lon': -80.5425333, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3994322, 'lon': -80.5458911, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3992299, 'lon': -80.5456219, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3990331, 'lon': -80.5452612, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3990479, 'lon': -80.544929, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3990726, 'lon': -80.5445554, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4015699, 'lon': -80.5444283, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4009973, 'lon': -80.545229, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4007525, 'lon': -80.546159, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4017578, 'lon': -80.5445349, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4020461, 'lon': -80.5433953, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4025386, 'lon': -80.5438727, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4022441, 'lon': -80.542874, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.403178, 'lon': -80.5421776, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4033865, 'lon': -80.5427535, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4033608, 'lon': -80.5431035, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.40295, 'lon': -80.5443354, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4021665, 'lon': -80.5450336, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.403128, 'lon': -80.5451039, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4013725, 'lon': -80.5463132, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4016068, 'lon': -80.5460724, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3962116, 'lon': -80.5463616, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.3970473, 'lon': -80.5456856, 'tags': {'leisure': 'swimming_pool'}}
# {'lat': 43.4085147, 'lon': -80.4870212, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4096988, 'lon': -80.4869366, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4078996, 'lon': -80.487049, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.407781, 'lon': -80.4881615, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4070165, 'lon': -80.48836, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4102734, 'lon': -80.4881411, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4104933, 'lon': -80.4882954, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4060971, 'lon': -80.4884187, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}
# {'lat': 43.4063189, 'lon': -80.4883068, 'tags': {'access': 'private', 'leisure': 'swimming_pool'}}

# %%
import pandas as pd
pools_df = pd.DataFrame(pools)
print(pools_df.head())
# Out:
#          lat        lon                                               tags
# 0  43.312810 -80.611900  {'access': 'private', 'building': 'yes', 'leis...
# 1  43.329218 -80.809291                       {'leisure': 'swimming_pool'}
# 2  43.328912 -80.807952                       {'leisure': 'swimming_pool'}
# 3  43.368118 -81.001000                       {'leisure': 'swimming_pool'}
# 4  43.370764 -80.975889   {'leisure': 'swimming_pool', 'natural': 'water'}

# %%
pools_df.to_csv("osm_sample_output.csv", index=False)

# %%
import pandas as pd
pools_df = pd.read_csv("osm_sample_output.csv")
pools_dict = pools_df.to_dict(orient='records')
print(pools_dict[:5])
# Out:
# [{'lat': 43.31281, 'lon': -80.6119001, 'tags': "{'access': 'private', 'building': 'yes', 'leisure': 'swimming_pool'}"}, {'lat': 43.3292184, 'lon': -80.8092907, 'tags': "{'leisure': 'swimming_pool'}"}, {'lat': 43.3289124, 'lon': -80.8079521, 'tags': "{'leisure': 'swimming_pool'}"}, {'lat': 43.3681181, 'lon': -81.0010002, 'tags': "{'leisure': 'swimming_pool'}"}, {'lat': 43.3707635, 'lon': -80.9758888, 'tags': "{'leisure': 'swimming_pool', 'natural': 'water'}"}]

# %%
pools = pools_dict

# %% [markdown]
# ## Step 2: Address Option Collection

# %%
import os
import requests
import time
import json

def get_possible_addresses(lat, lon, api_key):
    """
    Reverse geocode a lat/lon using Google Maps API.
    Returns a list of enriched address objects including simplified components and lat/lon.
    """
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "latlng": f"{lat},{lon}",
        "key": api_key
    }
    
    try:
        response = requests.get(base_url, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data["status"] == "OK":
            enriched_results = []
            for result in data["results"]:
                location = result.get("geometry", {}).get("location", {})
                raw_components = result.get("address_components", [])
                
                # Parse and simplify components
                parsed_components = {
                    "address_number": None,
                    "street_name": None,
                    "locality": None,
                    "county": None,
                    "province_state": None,
                    "postal_code": None,
                    "country": None
                }
                
                for comp in raw_components:
                    types = comp.get("types", [])
                    if "street_number" in types:
                        parsed_components["address_number"] = comp["long_name"]
                    elif "route" in types:
                        parsed_components["street_name"] = comp["long_name"]
                    elif "locality" in types:
                        parsed_components["locality"] = comp["long_name"]
                    elif "administrative_area_level_2" in types:
                        parsed_components["county"] = comp["long_name"]
                    elif "administrative_area_level_1" in types:
                        parsed_components["province_state"] = comp["long_name"]
                    elif "postal_code" in types:
                        parsed_components["postal_code"] = comp["long_name"]
                    elif "country" in types:
                        parsed_components["country"] = comp["long_name"]
                    elif "administrative_area_level_3" in types and not parsed_components["locality"]:
                        # Sometimes level 3 can be a city if locality is missing
                        parsed_components["locality"] = comp["long_name"]

                enriched_results.append({
                    "formatted_address": result.get("formatted_address"),
                    "address_components": parsed_components,     # Simplified dictionary
                    "raw_components": raw_components,            # Original list
                    "place_id": result.get("place_id"),
                    "location_type": result.get("geometry", {}).get("location_type"),
                    "types": result.get("types"),
                    "lat": location.get("lat"),
                    "lon": location.get("lng")
                })
            return enriched_results
            
        elif data["status"] == "ZERO_RESULTS":
            print(f"  No address found for {lat}, {lon}")
            return []
        else:
            print(f"  Geocoding error for {lat}, {lon}: {data['status']}")
            if "error_message" in data:
                print(f"  Error message: {data['error_message']}")
            return []
            
    except Exception as e:
        print(f"  Request error: {e}")
        return []

def collect_addresses_for_pools(pools, api_key):
    """
    Iterates through pools and adds 'possible_addresses' field.
    """
    enriched_pools = []
    total = len(pools)
    
    print(f"Starting address collection for {total} pools...")
    
    for i, pool in enumerate(pools, 1):
        lat, lon = pool["lat"], pool["lon"]
        print(f"[{i}/{total}] Geocoding {lat:.5f}, {lon:.5f}...")
        
        address_results = get_possible_addresses(lat, lon, api_key)
        
        pool_copy = pool.copy()
        pool_copy["possible_addresses"] = address_results
        enriched_pools.append(pool_copy)
        
        if address_results:
             best = address_results[0]
             print(f"  -> Found {len(address_results)} options. Best match: {best.get('formatted_address')}")
        else:
             print("  -> No addresses returned.")
        
        # Respect API rate limits
        time.sleep(0.1)
        
    return enriched_pools

# Retrieve API key from environment variable
GOOGLE_API_KEY = os.environ.get("GOOGLE_MAPS_API_KEY", "")

if __name__ == "__main__":
    if GOOGLE_API_KEY == "NOTHING":
        print("WARNING: Please set your GOOGLE_MAPS_API_KEY environment variable or replace the placeholder string.")
    else:
        # Assuming 'pools' variable is available from previous cells
        if 'pools' in locals() and pools:
             print("Test run on first 3 pools:")
             # Limit to first 3 for testing to avoid excessive API usage/cost during dev
              
             enriched_sample = collect_addresses_for_pools(pools, GOOGLE_API_KEY)
             
             print("\n--- Results ---")
             for p in enriched_sample:
                 print(f"Pool: {p['lat']}, {p['lon']}")
                 if p.get('possible_addresses'):
                     first_match = p['possible_addresses'][0]
                     print(f"Best Address: {first_match['formatted_address']}")
                     print(f"Address Coords: {first_match.get('lat')}, {first_match.get('lon')}")
                     
                     comps = first_match['address_components']
                     print(f"Parsed Components:")
                     print(f"  Number: {comps.get('address_number')}")
                     print(f"  Street: {comps.get('street_name')}")
                     print(f"  City:   {comps.get('locality')}")
                     print(f"  State:  {comps.get('province_state')}")
                 else:
                     print("No address found")
                 print("-" * 20)
        else:
            print("No 'pools' variable found. Run the OSM collection steps first.")
# Out:
# Test run on first 3 pools:
# Starting address collection for 117 pools...
# [1/117] Geocoding 43.31281, -80.61190...
#   -> Found 12 options. Best match: 876764 Hofstetter Rd, Plattsville, ON N0J 1S0, Canada
# [2/117] Geocoding 43.32922, -80.80929...
#   -> Found 12 options. Best match: 657185 15th Line, Tavistock, ON N0B 2R0, Canada
# [3/117] Geocoding 43.32891, -80.80795...
#   -> Found 12 options. Best match: 657174 15th Line, Tavistock, ON N0B 2R0, Canada
# [4/117] Geocoding 43.36812, -81.00100...
#   -> Found 14 options. Best match: 639 W Gore St, Stratford, ON N5A 1L4, Canada
# [5/117] Geocoding 43.37076, -80.97589...
#   -> Found 14 options. Best match: 176 Albert St, Stratford, ON N5A 3K6, Canada
# [6/117] Geocoding 43.37290, -80.98428...
#   -> Found 13 options. Best match: 15 William St, Stratford, ON N5A 4X9, Canada
# [7/117] Geocoding 43.37278, -80.98457...
#   -> Found 14 options. Best match: 15 William St, Stratford, ON N5A 4X9, Canada
# [8/117] Geocoding 43.37134, -80.93338...
#   -> Found 12 options. Best match: 2970B Line 34, Perth East, ON N5A 6S5, Canada
# [9/117] Geocoding 43.37078, -80.91327...
#   -> Found 10 options. Best match: 2808A Line 34, Perth East, ON N5A 6S5, Canada
# [10/117] Geocoding 43.37449, -80.72818...
#   -> Found 10 options. Best match: 196F Perth St, New Hamburg, ON N3A 4J2, Canada
# [11/117] Geocoding 43.38840, -80.96237...
#   -> Found 13 options. Best match: 379 Romeo St N, Stratford, ON N5A 0K4, Canada
# [12/117] Geocoding 43.38627, -80.72881...
#   -> Found 10 options. Best match: 1195 Perth St, New Hamburg, ON N3A 1S1, Canada
# [13/117] Geocoding 43.37792, -80.70655...
#   -> Found 12 options. Best match: 209 Jacob St, New Hamburg, ON N3A 1C5, Canada
# [14/117] Geocoding 43.39388, -80.54672...
#   -> Found 10 options. Best match: 12 Shadybrook Ct, Mannheim, ON N0B 2H0, Canada
# [15/117] Geocoding 43.39538, -80.53986...
#   -> Found 12 options. Best match: 29 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [16/117] Geocoding 43.39531, -80.54057...
#   -> Found 12 options. Best match: 45 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [17/117] Geocoding 43.39539, -80.54041...
#   -> Found 12 options. Best match: 37 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [18/117] Geocoding 43.39540, -80.54326...
#   -> Found 11 options. Best match: 112 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [19/117] Geocoding 43.39491, -80.54359...
#   -> Found 10 options. Best match: 120 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# [20/117] Geocoding 43.39443, -80.54294...
#   -> Found 11 options. Best match: 117 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [21/117] Geocoding 43.39498, -80.54226...
#   -> Found 12 options. Best match: 91 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [22/117] Geocoding 43.39523, -80.54152...
#   -> Found 12 options. Best match: 71 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [23/117] Geocoding 43.39464, -80.54344...
#   -> Found 10 options. Best match: 125 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# [24/117] Geocoding 43.39128, -80.54501...
#   -> Found 10 options. Best match: 66 Shadybrook Ct, Petersburg, ON N0B 2H0, Canada
# [25/117] Geocoding 43.39483, -80.54503...
#   -> Found 10 options. Best match: 1500 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# [26/117] Geocoding 43.39403, -80.54475...
#   -> Found 10 options. Best match: 1488 Mannheim Rd, Wilmot, ON N0B 2H0, Canada
# [27/117] Geocoding 43.39373, -80.54562...
#   -> Found 10 options. Best match: 23 Shadybrook Ct, Petersburg, ON N0B 2H0, Canada
# [28/117] Geocoding 43.39308, -80.54642...
#   -> Found 10 options. Best match: 30 Shadybrook Ct, Wilmot, ON N0B 2H0, Canada
# [29/117] Geocoding 43.39542, -80.54530...
#   -> Found 10 options. Best match: 1520 Mannheim Rd, Wilmot, ON N0B 2H0, Canada
# [30/117] Geocoding 43.39246, -80.52912...
#   -> Found 14 options. Best match: 1084 Trussler Rd, Kitchener, ON N2R 1S4, Canada
# [31/117] Geocoding 43.39244, -80.52824...
#   -> Found 14 options. Best match: 1104 Trussler Rd, Kitchener, ON N2R 1S4, Canada
# [32/117] Geocoding 43.38625, -80.49775...
#   -> Found 14 options. Best match: 30 Forest Grove Ln, Kitchener, ON N2R 1P6, Canada
# [33/117] Geocoding 43.38640, -80.49683...
#   -> Found 13 options. Best match: 10 Forest Grove Ln, Kitchener, ON N2R 0G3, Canada
# [34/117] Geocoding 43.40496, -80.72482...
#   -> Found 8 options. Best match: C73G+X3 Wilmot, ON, Canada
# [35/117] Geocoding 43.39869, -80.54708...
#   -> Found 10 options. Best match: 7 Cloverdale Crescent, Petersburg, ON N0B 2H0, Canada
# [36/117] Geocoding 43.39905, -80.54732...
#   -> Found 10 options. Best match: 6 Cloverdale Crescent, Wilmot, ON N0B 2H0, Canada
# [37/117] Geocoding 43.40129, -80.54817...
#   -> Found 11 options. Best match: 108 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [38/117] Geocoding 43.40207, -80.54695...
#   -> Found 11 options. Best match: 84 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [39/117] Geocoding 43.39693, -80.54794...
#   -> Found 11 options. Best match: 8 Cedarbrook Ct, Wilmot, ON N0B 2H0, Canada
# [40/117] Geocoding 43.39735, -80.54708...
#   -> Found 11 options. Best match: 3 Cedarbrook Ct, Petersburg, ON N0B 2H0, Canada
# [41/117] Geocoding 43.39704, -80.53703...
#   -> Found 11 options. Best match: 187 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [42/117] Geocoding 43.39776, -80.53629...
#   -> Found 11 options. Best match: 207 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [43/117] Geocoding 43.39875, -80.53909...
#   -> Found 10 options. Best match: 275 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [44/117] Geocoding 43.39834, -80.53693...
#   -> Found 11 options. Best match: 223 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [45/117] Geocoding 43.39679, -80.53791...
#   -> Found 11 options. Best match: 163 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [46/117] Geocoding 43.39661, -80.53909...
#   -> Found 11 options. Best match: 139 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [47/117] Geocoding 43.39860, -80.54014...
#   -> Found 10 options. Best match: 307 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [48/117] Geocoding 43.39789, -80.53843...
#   -> Found 11 options. Best match: 266 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [49/117] Geocoding 43.39795, -80.53817...
#   -> Found 11 options. Best match: 266 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [50/117] Geocoding 43.39753, -80.53885...
#   -> Found 11 options. Best match: 144 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [51/117] Geocoding 43.39729, -80.54033...
#   -> Found 11 options. Best match: 112 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [52/117] Geocoding 43.39724, -80.54168...
#   -> Found 11 options. Best match: 76 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [53/117] Geocoding 43.39759, -80.54172...
#   -> Found 11 options. Best match: 23 Meadowcliff Pl, Wilmot, ON N0B 2H0, Canada
# [54/117] Geocoding 43.39807, -80.54158...
#   -> Found 10 options. Best match: 33 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# [55/117] Geocoding 43.39839, -80.54224...
#   -> Found 11 options. Best match: 44 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# [56/117] Geocoding 43.39786, -80.54294...
#   -> Found 11 options. Best match: 38 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# [57/117] Geocoding 43.39737, -80.54292...
#   -> Found 11 options. Best match: 22 Meadowcliff Pl, Wilmot, ON N0B 2H0, Canada
# [58/117] Geocoding 43.39641, -80.54062...
#   -> Found 11 options. Best match: 95 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [59/117] Geocoding 43.39565, -80.53959...
#   -> Found 11 options. Best match: 23 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# [60/117] Geocoding 43.39774, -80.53795...
#   -> Found 11 options. Best match: 168 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [61/117] Geocoding 43.39649, -80.54126...
#   -> Found 11 options. Best match: 77 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [62/117] Geocoding 43.39607, -80.54094...
#   -> Found 11 options. Best match: 48 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [63/117] Geocoding 43.39601, -80.54061...
#   -> Found 11 options. Best match: 38 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [64/117] Geocoding 43.39574, -80.54258...
#   -> Found 12 options. Best match: 92 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# [65/117] Geocoding 43.39638, -80.54174...
#   -> Found 11 options. Best match: 69 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# [66/117] Geocoding 43.39617, -80.54271...
#   -> Found 11 options. Best match: 35 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [67/117] Geocoding 43.39596, -80.54299...
#   -> Found 12 options. Best match: 25 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [68/117] Geocoding 43.39585, -80.54324...
#   -> Found 11 options. Best match: 25 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [69/117] Geocoding 43.39663, -80.54444...
#   -> Found 11 options. Best match: 1543 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# [70/117] Geocoding 43.39672, -80.54390...
#   -> Found 11 options. Best match: 14 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# [71/117] Geocoding 43.39948, -80.53971...
#   -> Found 10 options. Best match: 1044 Knechtel Ct, Wilmot, ON N0B 2H0, Canada
# [72/117] Geocoding 43.39954, -80.54116...
#   -> Found 10 options. Best match: 9 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [73/117] Geocoding 43.40016, -80.54078...
#   -> Found 10 options. Best match: 36 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [74/117] Geocoding 43.39921, -80.54221...
#   -> Found 11 options. Best match: 1076 Bleams Rd, Wilmot, ON N0B 2H0, Canada
# [75/117] Geocoding 43.40136, -80.54030...
#   -> Found 11 options. Best match: 31 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [76/117] Geocoding 43.40142, -80.54017...
#   -> Found 11 options. Best match: 31 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [77/117] Geocoding 43.40176, -80.54097...
#   -> Found 10 options. Best match: 13 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [78/117] Geocoding 43.40212, -80.54105...
#   -> Found 10 options. Best match: 7 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [79/117] Geocoding 43.40088, -80.54141...
#   -> Found 10 options. Best match: 24 John Ross Ct, Petersburg, ON N0B 2H0, Canada
# [80/117] Geocoding 43.40046, -80.54028...
#   -> Found 10 options. Best match: 42 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# [81/117] Geocoding 43.40057, -80.54352...
#   -> Found 11 options. Best match: 196 Milne Dr, Petersburg, ON N0B 2H0, Canada
# [82/117] Geocoding 43.40026, -80.54446...
#   -> Found 11 options. Best match: 178 Milne Dr, Wilmot, ON N0B 2H0, Canada
# [83/117] Geocoding 43.40004, -80.54538...
#   -> Found 11 options. Best match: 160 Milne Dr, Wilmot, ON N0B 2H0, Canada
# [84/117] Geocoding 43.40007, -80.54304...
#   -> Found 10 options. Best match: 48 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [85/117] Geocoding 43.39999, -80.54358...
#   -> Found 10 options. Best match: 68 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [86/117] Geocoding 43.40012, -80.54253...
#   -> Found 10 options. Best match: 38 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [87/117] Geocoding 43.39943, -80.54589...
#   -> Found 10 options. Best match: 121 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [88/117] Geocoding 43.39923, -80.54562...
#   -> Found 11 options. Best match: 115 Mannheim Crescent, Petersburg, ON N0B 2H0, Canada
# [89/117] Geocoding 43.39903, -80.54526...
#   -> Found 11 options. Best match: 109 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [90/117] Geocoding 43.39905, -80.54493...
#   -> Found 11 options. Best match: 103 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [91/117] Geocoding 43.39907, -80.54456...
#   -> Found 11 options. Best match: 101 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# [92/117] Geocoding 43.40157, -80.54443...
#   -> Found 11 options. Best match: 11 Milne Dr, Petersburg, ON N0B 2H0, Canada
# [93/117] Geocoding 43.40100, -80.54523...
#   -> Found 11 options. Best match: 169 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [94/117] Geocoding 43.40075, -80.54616...
#   -> Found 11 options. Best match: 151 Milne Dr, Wilmot, ON N0B 2H0, Canada
# [95/117] Geocoding 43.40176, -80.54453...
#   -> Found 11 options. Best match: 19 Milne Dr, Wilmot, ON N0B 2H0, Canada
# [96/117] Geocoding 43.40205, -80.54340...
#   -> Found 11 options. Best match: 12 Milne Dr, Petersburg, ON N0B 2H0, Canada
# [97/117] Geocoding 43.40254, -80.54387...
#   -> Found 11 options. Best match: 24 Milne Dr, Petersburg, ON N0B 2H0, Canada
# [98/117] Geocoding 43.40224, -80.54287...
#   -> Found 11 options. Best match: 10 Burkle Toman Ct, Wilmot, ON N0B 2H0, Canada
# [99/117] Geocoding 43.40318, -80.54218...
#   -> Found 12 options. Best match: 43 Burkle Toman Ct, Petersburg, ON N0B 2H0, Canada
# [100/117] Geocoding 43.40339, -80.54275...
#   -> Found 12 options. Best match: 37 Burkle Toman Ct, Mannheim, ON N0B 2H0, Canada
# [101/117] Geocoding 43.40336, -80.54310...
#   -> Found 12 options. Best match: 31 Burkle Toman Ct, Mannheim, ON N0B 2H0, Canada
# [102/117] Geocoding 43.40295, -80.54434...
#   -> Found 11 options. Best match: 39 Burkle Toman Ct, Wilmot, ON N0B 2H0, Canada
# [103/117] Geocoding 43.40217, -80.54503...
#   -> Found 11 options. Best match: 51 Milne Dr, Wilmot, ON N0B 2H0, Canada
# [104/117] Geocoding 43.40313, -80.54510...
#   -> Found 11 options. Best match: 46 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [105/117] Geocoding 43.40137, -80.54631...
#   -> Found 11 options. Best match: 89 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [106/117] Geocoding 43.40161, -80.54607...
#   -> Found 11 options. Best match: 77 Milne Dr, Mannheim, ON N0B 2H0, Canada
# [107/117] Geocoding 43.39621, -80.54636...
#   -> Found 10 options. Best match: 27 Cedarbrook Ct, Petersburg, ON N0B 2H0, Canada
# [108/117] Geocoding 43.39705, -80.54569...
#   -> Found 11 options. Best match: 1558 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# [109/117] Geocoding 43.40851, -80.48702...
#   -> Found 13 options. Best match: 23 Yarwood Pl, Kitchener, ON N2E 2T6, Canada
# [110/117] Geocoding 43.40970, -80.48694...
#   -> Found 14 options. Best match: 208 Rittenhouse Rd, Kitchener, ON N2E 2X8, Canada
# [111/117] Geocoding 43.40790, -80.48705...
#   -> Found 13 options. Best match: 43 Ashley Ct, Kitchener, ON N2E 2Z7, Canada
# [112/117] Geocoding 43.40778, -80.48816...
#   -> Found 13 options. Best match: 47 Pipers Green Ct, Kitchener, ON N2E 3C6, Canada
# [113/117] Geocoding 43.40702, -80.48836...
#   -> Found 14 options. Best match: 27 Pipers Green Ct, Kitchener, ON N2E 3C5, Canada
# [114/117] Geocoding 43.41027, -80.48814...
#   -> Found 13 options. Best match: 780 Erinbrook Dr, Kitchener, ON N2E 2S7, Canada
# [115/117] Geocoding 43.41049, -80.48830...
#   -> Found 13 options. Best match: 772 Erinbrook Dr, Kitchener, ON N2E 2S7, Canada
# [116/117] Geocoding 43.40610, -80.48842...
#   -> Found 13 options. Best match: 129 Erinbrook Dr, Kitchener, ON N2E 3B7, Canada
# [117/117] Geocoding 43.40632, -80.48831...
#   -> Found 13 options. Best match: 6 Bonnybank Ct, Kitchener, ON N2E 3B9, Canada
#
# --- Results ---
# Pool: 43.31281, -80.6119001
# Best Address: 876764 Hofstetter Rd, Plattsville, ON N0J 1S0, Canada
# Address Coords: 43.3126263, -80.6122852
# Parsed Components:
#   Number: 876764
#   Street: Hofstetter Road
#   City:   Plattsville
#   State:  Ontario
# --------------------
# Pool: 43.3292184, -80.8092907
# Best Address: 657185 15th Line, Tavistock, ON N0B 2R0, Canada
# Address Coords: 43.3292668, -80.80910340000001
# Parsed Components:
#   Number: 657185
#   Street: 15th Line
#   City:   Tavistock
#   State:  Ontario
# --------------------
# Pool: 43.3289124, -80.8079521
# Best Address: 657174 15th Line, Tavistock, ON N0B 2R0, Canada
# Address Coords: 43.3287847, -80.80807449999999
# Parsed Components:
#   Number: 657174
#   Street: 15th Line
#   City:   Tavistock
#   State:  Ontario
# --------------------
# Pool: 43.3681181, -81.0010002
# Best Address: 639 W Gore St, Stratford, ON N5A 1L4, Canada
# Address Coords: 43.3682221, -81.000457
# Parsed Components:
#   Number: 639
#   Street: West Gore Street
#   City:   Stratford
#   State:  Ontario
# --------------------
# Pool: 43.3707635, -80.9758888
# Best Address: 176 Albert St, Stratford, ON N5A 3K6, Canada
# Address Coords: 43.3706335, -80.9760673
# Parsed Components:
#   Number: 176
#   Street: Albert Street
#   City:   Stratford
#   State:  Ontario
# --------------------
# Pool: 43.3728997, -80.9842785
# Best Address: 15 William St, Stratford, ON N5A 4X9, Canada
# Address Coords: 43.372921, -80.9845924
# Parsed Components:
#   Number: 15
#   Street: William Street
#   City:   Stratford
#   State:  Ontario
# --------------------
# Pool: 43.3727845, -80.984572
# Best Address: 15 William St, Stratford, ON N5A 4X9, Canada
# Address Coords: 43.3728465, -80.9847898
# Parsed Components:
#   Number: 15
#   Street: William Street
#   City:   Stratford
#   State:  Ontario
# --------------------
# Pool: 43.3713415, -80.9333756
# Best Address: 2970B Line 34, Perth East, ON N5A 6S5, Canada
# Address Coords: 43.3713809, -80.9334013
# Parsed Components:
#   Number: 2970B
#   Street: Line 34
#   City:   Perth East
#   State:  Ontario
# --------------------
# Pool: 43.3707833, -80.9132723
# Best Address: 2808A Line 34, Perth East, ON N5A 6S5, Canada
# Address Coords: 43.3709237, -80.9135932
# Parsed Components:
#   Number: 2808A
#   Street: Line 34
#   City:   Perth East
#   State:  Ontario
# --------------------
# Pool: 43.3744906, -80.7281767
# Best Address: 196F Perth St, New Hamburg, ON N3A 4J2, Canada
# Address Coords: 43.37418599999999, -80.7281739
# Parsed Components:
#   Number: 196F
#   Street: Perth Street
#   City:   New Hamburg
#   State:  Ontario
# --------------------
# Pool: 43.3884007, -80.9623719
# Best Address: 379 Romeo St N, Stratford, ON N5A 0K4, Canada
# Address Coords: 43.388171, -80.96255239999999
# Parsed Components:
#   Number: 379
#   Street: Romeo Street North
#   City:   Stratford
#   State:  Ontario
# --------------------
# Pool: 43.3862683, -80.7288056
# Best Address: 1195 Perth St, New Hamburg, ON N3A 1S1, Canada
# Address Coords: 43.3861621, -80.7289559
# Parsed Components:
#   Number: 1195
#   Street: Perth Street
#   City:   New Hamburg
#   State:  Ontario
# --------------------
# Pool: 43.3779191, -80.7065542
# Best Address: 209 Jacob St, New Hamburg, ON N3A 1C5, Canada
# Address Coords: 43.3778608, -80.7069094
# Parsed Components:
#   Number: 209
#   Street: Jacob Street
#   City:   New Hamburg
#   State:  Ontario
# --------------------
# Pool: 43.3938834, -80.5467198
# Best Address: 12 Shadybrook Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.3938609, -80.54651439999999
# Parsed Components:
#   Number: 12
#   Street: Shadybrook Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.3953808, -80.5398604
# Best Address: 29 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3955267, -80.5400469
# Parsed Components:
#   Number: 29
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3953094, -80.540567
# Best Address: 45 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.39544799999999, -80.5406551
# Parsed Components:
#   Number: 45
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3953935, -80.5404149
# Best Address: 37 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3955212, -80.5403656
# Parsed Components:
#   Number: 37
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.395396, -80.5432584
# Best Address: 112 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3952558, -80.54313309999999
# Parsed Components:
#   Number: 112
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.394908, -80.5435899
# Best Address: 120 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3949791, -80.54340429999999
# Parsed Components:
#   Number: 120
#   Street: Meadowpark Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3944276, -80.5429407
# Best Address: 117 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3946204, -80.5428467
# Parsed Components:
#   Number: 117
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3949832, -80.5422607
# Best Address: 91 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3951706, -80.54225149999999
# Parsed Components:
#   Number: 91
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3952342, -80.541522
# Best Address: 71 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3953723, -80.54162409999999
# Parsed Components:
#   Number: 71
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3946361, -80.5434417
# Best Address: 125 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3947312, -80.5432807
# Parsed Components:
#   Number: 125
#   Street: Meadowpark Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3912795, -80.54501
# Best Address: 66 Shadybrook Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3914883, -80.545194
# Parsed Components:
#   Number: 66
#   Street: Shadybrook Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3948266, -80.5450344
# Best Address: 1500 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3946903, -80.5448699
# Parsed Components:
#   Number: 1500
#   Street: Mannheim Road
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3940292, -80.544746
# Best Address: 1488 Mannheim Rd, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3941279, -80.5446233
# Parsed Components:
#   Number: 1488
#   Street: Mannheim Road
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.393726, -80.5456151
# Best Address: 23 Shadybrook Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.39370530000001, -80.5458233
# Parsed Components:
#   Number: 23
#   Street: Shadybrook Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.393085, -80.5464191
# Best Address: 30 Shadybrook Ct, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3931492, -80.5462333
# Parsed Components:
#   Number: 30
#   Street: Shadybrook Court
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3954185, -80.5452959
# Best Address: 1520 Mannheim Rd, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3955439, -80.54507459999999
# Parsed Components:
#   Number: 1520
#   Street: Mannheim Road
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3924602, -80.5291178
# Best Address: 1084 Trussler Rd, Kitchener, ON N2R 1S4, Canada
# Address Coords: 43.3926375, -80.5287518
# Parsed Components:
#   Number: 1084
#   Street: Trussler Road
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.3924352, -80.528237
# Best Address: 1104 Trussler Rd, Kitchener, ON N2R 1S4, Canada
# Address Coords: 43.3922488, -80.5283805
# Parsed Components:
#   Number: 1104
#   Street: Trussler Road
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.3862535, -80.4977499
# Best Address: 30 Forest Grove Ln, Kitchener, ON N2R 1P6, Canada
# Address Coords: 43.3861634, -80.4976269
# Parsed Components:
#   Number: 30
#   Street: Forest Grove Lane
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.3864028, -80.4968296
# Best Address: 10 Forest Grove Ln, Kitchener, ON N2R 0G3, Canada
# Address Coords: 43.3863017, -80.49682340000001
# Parsed Components:
#   Number: 10
#   Street: Forest Grove Lane
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4049602, -80.7248238
# Best Address: C73G+X3 Wilmot, ON, Canada
# Address Coords: 43.4049602, -80.7248238
# Parsed Components:
#   Number: None
#   Street: None
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3986874, -80.5470837
# Best Address: 7 Cloverdale Crescent, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3988772, -80.547023
# Parsed Components:
#   Number: 7
#   Street: Cloverdale Crescent
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3990485, -80.5473228
# Best Address: 6 Cloverdale Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3991411, -80.5470417
# Parsed Components:
#   Number: 6
#   Street: Cloverdale Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4012943, -80.5481653
# Best Address: 108 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4013073, -80.54779429999999
# Parsed Components:
#   Number: 108
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4020744, -80.5469479
# Best Address: 84 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.401987, -80.5467748
# Parsed Components:
#   Number: 84
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.3969312, -80.5479354
# Best Address: 8 Cedarbrook Ct, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.39689240000001, -80.54767869999999
# Parsed Components:
#   Number: 8
#   Street: Cedarbrook Court
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.397346, -80.547077
# Best Address: 3 Cedarbrook Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3972561, -80.5472352
# Parsed Components:
#   Number: 3
#   Street: Cedarbrook Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3970375, -80.5370349
# Best Address: 187 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3972553, -80.5371523
# Parsed Components:
#   Number: 187
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3977601, -80.5362861
# Best Address: 207 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3978162, -80.5365885
# Parsed Components:
#   Number: 207
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3987526, -80.5390873
# Best Address: 275 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3985503, -80.53894939999999
# Parsed Components:
#   Number: 275
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3983405, -80.5369303
# Best Address: 223 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3981952, -80.53702620000001
# Parsed Components:
#   Number: 223
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3967914, -80.5379085
# Best Address: 163 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3970227, -80.538091
# Parsed Components:
#   Number: 163
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.396605, -80.5390943
# Best Address: 139 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3967766, -80.5390252
# Parsed Components:
#   Number: 139
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3986034, -80.5401394
# Best Address: 307 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3984438, -80.54023620000001
# Parsed Components:
#   Number: 307
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3978862, -80.53843
# Best Address: 266 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3980858, -80.5384842
# Parsed Components:
#   Number: 266
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3979502, -80.5381699
# Best Address: 266 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3980858, -80.5384842
# Parsed Components:
#   Number: 266
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3975263, -80.5388541
# Best Address: 144 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.39731829999999, -80.53888909999999
# Parsed Components:
#   Number: 144
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3972877, -80.5403293
# Best Address: 112 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3971434, -80.5402022
# Parsed Components:
#   Number: 112
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3972445, -80.5416838
# Best Address: 76 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.39710119999999, -80.5415373
# Parsed Components:
#   Number: 76
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3975868, -80.5417215
# Best Address: 23 Meadowcliff Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3975891, -80.5419363
# Parsed Components:
#   Number: 23
#   Street: Meadowcliff Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.398066, -80.541579
# Best Address: 33 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3979042, -80.5417897
# Parsed Components:
#   Number: 33
#   Street: Meadowcliff Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3983858, -80.5422368
# Best Address: 44 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3981883, -80.5424062
# Parsed Components:
#   Number: 44
#   Street: Meadowcliff Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3978564, -80.5429373
# Best Address: 38 Meadowcliff Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3979348, -80.542748
# Parsed Components:
#   Number: 38
#   Street: Meadowcliff Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3973671, -80.5429196
# Best Address: 22 Meadowcliff Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3974373, -80.5427091
# Parsed Components:
#   Number: 22
#   Street: Meadowcliff Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.396411, -80.5406201
# Best Address: 95 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3966062, -80.5406763
# Parsed Components:
#   Number: 95
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3956506, -80.5395855
# Best Address: 23 Meadowpark Pl, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.395747, -80.53983989999999
# Parsed Components:
#   Number: 23
#   Street: Meadowpark Place
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3977401, -80.53795
# Best Address: 168 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3975622, -80.5378817
# Parsed Components:
#   Number: 168
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3964919, -80.5412644
# Best Address: 77 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3966497, -80.5413683
# Parsed Components:
#   Number: 77
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3960698, -80.5409368
# Best Address: 48 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.395912, -80.5408273
# Parsed Components:
#   Number: 48
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3960065, -80.540606
# Best Address: 38 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3959525, -80.5404882
# Parsed Components:
#   Number: 38
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3957356, -80.5425791
# Best Address: 92 Meadowpark Pl, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.39561150000001, -80.54251649999999
# Parsed Components:
#   Number: 92
#   Street: Meadowpark Place
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3963848, -80.5417351
# Best Address: 69 Woodridge Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3966099, -80.5417013
# Parsed Components:
#   Number: 69
#   Street: Woodridge Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3961692, -80.5427133
# Best Address: 35 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.39615999999999, -80.54296579999999
# Parsed Components:
#   Number: 35
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3959605, -80.5429948
# Best Address: 25 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3960216, -80.5433024
# Parsed Components:
#   Number: 25
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.395853, -80.5432427
# Best Address: 25 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3960216, -80.5433024
# Parsed Components:
#   Number: 25
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3966323, -80.5444449
# Best Address: 1543 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3967057, -80.5446757
# Parsed Components:
#   Number: 1543
#   Street: Mannheim Road
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3967205, -80.5438956
# Best Address: 14 Woodridge Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3965342, -80.5438257
# Parsed Components:
#   Number: 14
#   Street: Woodridge Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3994792, -80.5397096
# Best Address: 1044 Knechtel Ct, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3993124, -80.53980340000001
# Parsed Components:
#   Number: 1044
#   Street: Knechtel Court
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3995351, -80.5411619
# Best Address: 9 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3995737, -80.5415107
# Parsed Components:
#   Number: 9
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4001611, -80.5407842
# Best Address: 36 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4005506, -80.54084999999999
# Parsed Components:
#   Number: 36
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.3992112, -80.5422131
# Best Address: 1076 Bleams Rd, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3991311, -80.5419447
# Parsed Components:
#   Number: 1076
#   Street: Bleams Road
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4013578, -80.5403041
# Best Address: 31 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.401212, -80.5404296
# Parsed Components:
#   Number: 31
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.401418, -80.5401699
# Best Address: 31 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.401212, -80.5404296
# Parsed Components:
#   Number: 31
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4017609, -80.5409739
# Best Address: 13 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4016708, -80.5411755
# Parsed Components:
#   Number: 13
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4021192, -80.5410531
# Best Address: 7 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4018447, -80.5413408
# Parsed Components:
#   Number: 7
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4008825, -80.5414052
# Best Address: 24 John Ross Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4009777, -80.5413335
# Parsed Components:
#   Number: 24
#   Street: John Ross Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4004568, -80.5402837
# Best Address: 42 John Ross Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4005833, -80.5404243
# Parsed Components:
#   Number: 42
#   Street: John Ross Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.400569, -80.5435178
# Best Address: 196 Milne Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4007288, -80.5436462
# Parsed Components:
#   Number: 196
#   Street: Milne Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4002599, -80.5444557
# Best Address: 178 Milne Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4003861, -80.5445503
# Parsed Components:
#   Number: 178
#   Street: Milne Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4000379, -80.5453772
# Best Address: 160 Milne Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4001947, -80.5454982
# Parsed Components:
#   Number: 160
#   Street: Milne Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4000656, -80.5430413
# Best Address: 48 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3999179, -80.54293729999999
# Parsed Components:
#   Number: 48
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3999936, -80.5435833
# Best Address: 68 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3998254, -80.54364869999999
# Parsed Components:
#   Number: 68
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4001166, -80.5425333
# Best Address: 38 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3999663, -80.5425904
# Parsed Components:
#   Number: 38
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3994322, -80.5458911
# Best Address: 121 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3995409, -80.54570609999999
# Parsed Components:
#   Number: 121
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3992299, -80.5456219
# Best Address: 115 Mannheim Crescent, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3993736, -80.54554
# Parsed Components:
#   Number: 115
#   Street: Mannheim Crescent
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3990331, -80.5452612
# Best Address: 109 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3992136, -80.54528359999999
# Parsed Components:
#   Number: 109
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3990479, -80.544929
# Best Address: 103 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3991974, -80.5448828
# Parsed Components:
#   Number: 103
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.3990726, -80.5445554
# Best Address: 101 Mannheim Crescent, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.3992035, -80.5445405
# Parsed Components:
#   Number: 101
#   Street: Mannheim Crescent
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4015699, -80.5444283
# Best Address: 11 Milne Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4016858, -80.5441787
# Parsed Components:
#   Number: 11
#   Street: Milne Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4009973, -80.545229
# Best Address: 169 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4008256, -80.544989
# Parsed Components:
#   Number: 169
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4007525, -80.546159
# Best Address: 151 Milne Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.400597, -80.54617689999999
# Parsed Components:
#   Number: 151
#   Street: Milne Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4017578, -80.5445349
# Best Address: 19 Milne Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4019141, -80.5443706
# Parsed Components:
#   Number: 19
#   Street: Milne Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4020461, -80.5433953
# Best Address: 12 Milne Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4020017, -80.54361039999999
# Parsed Components:
#   Number: 12
#   Street: Milne Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4025386, -80.5438727
# Best Address: 24 Milne Dr, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4023996, -80.5439942
# Parsed Components:
#   Number: 24
#   Street: Milne Drive
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4022441, -80.542874
# Best Address: 10 Burkle Toman Ct, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4024479, -80.54289159999999
# Parsed Components:
#   Number: 10
#   Street: Burkle Toman Court
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.403178, -80.5421776
# Best Address: 43 Burkle Toman Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.4029727, -80.54242670000001
# Parsed Components:
#   Number: 43
#   Street: Burkle Toman Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4033865, -80.5427535
# Best Address: 37 Burkle Toman Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4031946, -80.5428663
# Parsed Components:
#   Number: 37
#   Street: Burkle Toman Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4033608, -80.5431035
# Best Address: 31 Burkle Toman Ct, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.40320639999999, -80.5431651
# Parsed Components:
#   Number: 31
#   Street: Burkle Toman Court
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.40295, -80.5443354
# Best Address: 39 Burkle Toman Ct, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4027058, -80.5444151
# Parsed Components:
#   Number: 39
#   Street: Burkle Toman Court
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.4021665, -80.5450336
# Best Address: 51 Milne Dr, Wilmot, ON N0B 2H0, Canada
# Address Coords: 43.4022976, -80.5453471
# Parsed Components:
#   Number: 51
#   Street: Milne Drive
#   City:   Wilmot
#   State:  Ontario
# --------------------
# Pool: 43.403128, -80.5451039
# Best Address: 46 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4029322, -80.54518879999999
# Parsed Components:
#   Number: 46
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4013725, -80.5463132
# Best Address: 89 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4015233, -80.5464753
# Parsed Components:
#   Number: 89
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.4016068, -80.5460724
# Best Address: 77 Milne Dr, Mannheim, ON N0B 2H0, Canada
# Address Coords: 43.4017396, -80.54620229999999
# Parsed Components:
#   Number: 77
#   Street: Milne Drive
#   City:   Mannheim
#   State:  Ontario
# --------------------
# Pool: 43.3962116, -80.5463616
# Best Address: 27 Cedarbrook Ct, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.396321, -80.5464358
# Parsed Components:
#   Number: 27
#   Street: Cedarbrook Court
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.3970473, -80.5456856
# Best Address: 1558 Mannheim Rd, Petersburg, ON N0B 2H0, Canada
# Address Coords: 43.3970548, -80.54551289999999
# Parsed Components:
#   Number: 1558
#   Street: Mannheim Road
#   City:   Petersburg
#   State:  Ontario
# --------------------
# Pool: 43.4085147, -80.4870212
# Best Address: 23 Yarwood Pl, Kitchener, ON N2E 2T6, Canada
# Address Coords: 43.4085986, -80.4868925
# Parsed Components:
#   Number: 23
#   Street: Yarwood Place
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4096988, -80.4869366
# Best Address: 208 Rittenhouse Rd, Kitchener, ON N2E 2X8, Canada
# Address Coords: 43.4096996, -80.4867695
# Parsed Components:
#   Number: 208
#   Street: Rittenhouse Road
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4078996, -80.487049
# Best Address: 43 Ashley Ct, Kitchener, ON N2E 2Z7, Canada
# Address Coords: 43.4077808, -80.48688190000001
# Parsed Components:
#   Number: 43
#   Street: Ashley Court
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.407781, -80.4881615
# Best Address: 47 Pipers Green Ct, Kitchener, ON N2E 3C6, Canada
# Address Coords: 43.4077429, -80.4880276
# Parsed Components:
#   Number: 47
#   Street: Pipers Green Court
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4070165, -80.48836
# Best Address: 27 Pipers Green Ct, Kitchener, ON N2E 3C5, Canada
# Address Coords: 43.4070729, -80.48820200000002
# Parsed Components:
#   Number: 27
#   Street: Pipers Green Court
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4102734, -80.4881411
# Best Address: 780 Erinbrook Dr, Kitchener, ON N2E 2S7, Canada
# Address Coords: 43.41029930000001, -80.4879414
# Parsed Components:
#   Number: 780
#   Street: Erinbrook Drive
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4104933, -80.4882954
# Best Address: 772 Erinbrook Dr, Kitchener, ON N2E 2S7, Canada
# Address Coords: 43.4105788, -80.48815859999999
# Parsed Components:
#   Number: 772
#   Street: Erinbrook Drive
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4060971, -80.4884187
# Best Address: 129 Erinbrook Dr, Kitchener, ON N2E 3B7, Canada
# Address Coords: 43.4060131, -80.48833379999999
# Parsed Components:
#   Number: 129
#   Street: Erinbrook Drive
#   City:   Kitchener
#   State:  Ontario
# --------------------
# Pool: 43.4063189, -80.4883068
# Best Address: 6 Bonnybank Ct, Kitchener, ON N2E 3B9, Canada
# Address Coords: 43.4061925, -80.4885595
# Parsed Components:
#   Number: 6
#   Street: Bonnybank Court
#   City:   Kitchener
#   State:  Ontario
# --------------------

# %%
# now we extract all of the actual addresses, and put them into their own df for passing into the validation system


def extract_all_addresses(pools):
    all_addresses = []
    for pool in pools:
        for addr in pool.get("possible_addresses", []):
            components = addr.get("address_components", {})
            all_addresses.append({
                "lat": addr.get("lat"),
                "lon": addr.get("lon"),
                "formatted_address": addr.get("formatted_address"),
                "address_number": components.get("address_number"),
                "street_name": components.get("street_name"),
                "locality": components.get("locality"),
                "province_state": components.get("province_state"),
                "postal_code": components.get("postal_code"),
                "country": components.get("country")
            })
    
    # drop all rows where address_number is none, or address_number contains a range (ie. "123-125")
    all_addresses = [a for a in all_addresses if a["address_number"] and not any(c in a["address_number"] for c in "-–")]
    
    #drop duplicates based on formatted_address column
    seen = set()
    unique_addresses = []
    for addr in all_addresses:
        if addr["formatted_address"] not in seen:
            seen.add(addr["formatted_address"])
            unique_addresses.append(addr)
    print(f"Extracted {len(all_addresses)} addresses, {len(unique_addresses)} unique after filtering.")
    
    return unique_addresses  
addresses = extract_all_addresses(enriched_sample)
addresses_df = pd.DataFrame(addresses)
addresses_df.head(10)
# Out:
# Extracted 351 addresses, 280 unique after filtering.
#          lat        lon                                  formatted_address  \
# 0  43.312626 -80.612285  876764 Hofstetter Rd, Plattsville, ON N0J 1S0,...
# 1  43.313193 -80.612254  876768 Hofstetter Rd, Plattsville, ON N0J 1S0,...
# 2  43.312711 -80.612412  876746 Hofstetter Rd, Plattsville, ON N0J 1S0,...
# 3  43.310711 -80.613081  48 English Cres, Blandford-Blenheim, ON N0J 1S...
# 4  43.329267 -80.809103    657185 15th Line, Tavistock, ON N0B 2R0, Canada
# 5  43.329071 -80.809737  985420 Perth-Oxford Rd, Tavistock, ON N0B 2R0,...
# 6  43.329242 -80.808340  985434 Perth-Oxford Rd, Tavistock, ON N0B 2R0,...
# 7  43.329374 -80.808733  657185 15th Line, East Zorra-Tavistock, ON N0B...
# 8  43.328785 -80.808074    657174 15th Line, Tavistock, ON N0B 2R0, Canada
# 9  43.328644 -80.808334  657175 15th Line, East Zorra-Tavistock, ON N0B...
#
#   address_number        street_name              locality province_state  \
# 0         876764    Hofstetter Road           Plattsville        Ontario
# 1         876768    Hofstetter Road           Plattsville        Ontario
# 2         876746    Hofstetter Road           Plattsville        Ontario
# 3             48   English Crescent    Blandford-Blenheim        Ontario
# 4         657185          15th Line             Tavistock        Ontario
# 5         985420  Perth-Oxford Road             Tavistock        Ontario
# 6         985434  Perth-Oxford Road             Tavistock        Ontario
# 7         657185          15th Line  East Zorra-Tavistock        Ontario
# 8         657174          15th Line             Tavistock        Ontario
# 9         657175          15th Line  East Zorra-Tavistock        Ontario
#
#   postal_code country
# 0     N0J 1S0  Canada
# 1     N0J 1S0  Canada
# 2     N0J 1S0  Canada
# 3     N0J 1S0  Canada
# 4     N0B 2R0  Canada
# 5     N0B 2R0  Canada
# 6     N0B 2R0  Canada
# 7     N0B 2R0  Canada
# 8     N0B 2R0  Canada
# 9     N0B 2R0  Canada

# %%
from shapely.geometry import Point

def upsert_addresses_to_stage_db(address_df, conn):
    if 'geom' not in address_df.columns or address_df['geom'].dtype == 'object':
        address_df['geom'] = address_df.apply(lambda row: Point(row['lon'], row['lat']), axis=1)
    
    # Rename locality to municipality
    address_df.rename(columns={"locality": "municipality"}, inplace=True)
    
    # Select and order columns for insertion (no address_id - DB generates it)
    columns_address_df = ['address_number', 'lat', 'lon', 'postal_code', 
                          'street_name', 'province_state', 'country', 'municipality']
    address_df = address_df[columns_address_df]
    
    # Insert into address table (deduplication handled pre-insert)
    cursor = conn.cursor()
    inserted_count = 0
    
    insert_sql = """
    INSERT INTO address (address_number, lat, lon, postal_code, street_name, 
                        province_state, country, geom, municipality)
    VALUES (%s, %s, %s, %s, %s, %s, %s, ST_SetSRID(ST_MakePoint(%s, %s), 4326), %s)
    RETURNING id;
    """
    
    try:
        for idx, row in address_df.iterrows():
            cursor.execute(insert_sql, (
                row['address_number'],
                row['lat'],
                row['lon'],
                row['postal_code'],
                row['street_name'],
                row['province_state'],
                row['country'],
                row['lon'],  # For ST_MakePoint
                row['lat'],  # For ST_MakePoint
                row['municipality']
            ))
            cursor.fetchone()  # Get the returned id
            inserted_count += 1
        
        conn.commit()
        print(f"Inserted {inserted_count} addresses successfully.")
        return inserted_count
        
    except Exception as e:
        conn.rollback()
        print(f"Error during insert: {e}")
        raise
    finally:
        cursor.close()

def upsert_pools_to_stage_db(pools_df, conn):
    """
    Insert pools into the pool table (deduplication handled pre-insert).
    Expects pools_df to have 'lat', 'lon', and optionally 'tags' or 'pool_type' columns.
    """
    # Extract pool_type from tags if it exists, otherwise default to 'unknown'
    if 'pool_type' not in pools_df.columns:
        if 'tags' in pools_df.columns:
            pools_df['pool_type'] = pools_df['tags'].apply(
                lambda x: x.get('leisure', x.get('swimming_pool', 'unknown')) if isinstance(x, dict) else 'unknown'
            )
        else:
            pools_df['pool_type'] = 'unknown'
    
    # Select columns for insertion (no pool_id - DB generates it)
    columns_pool_df = ['lat', 'lon', 'pool_type']
    pools_df = pools_df[columns_pool_df]
    
    # Insert into pool table
    cursor = conn.cursor()
    inserted_count = 0
    
    insert_sql = """
    INSERT INTO pool (lat, lon, pool_type)
    VALUES (%s, %s, %s)
    RETURNING id;
    """
    
    try:
        for idx, row in pools_df.iterrows():
            cursor.execute(insert_sql, (
                row['lat'],
                row['lon'],
                row['pool_type']
            ))
            cursor.fetchone()  # Get the returned id
            inserted_count += 1
        
        conn.commit()
        print(f"Inserted {inserted_count} pools successfully.")
        return inserted_count
        
    except Exception as e:
        conn.rollback()
        print(f"Error during insert: {e}")
        raise
    finally:
        cursor.close()

# %%
import psycopg2
NEON_DSN = ''
try:
    conn = psycopg2.connect(NEON_DSN)
    print("Connected to Neon database successfully.")
    
    # Upsert addresses first to ensure we have address_ids for any future relationships
    if 'addresses_df' in locals():
        upsert_addresses_to_stage_db(addresses_df, conn)
    else:
        print("No addresses_df found. Skipping address upsert.")
    
    # Upsert pools
    if 'pools_df' in locals():
        upsert_pools_to_stage_db(pools_df, conn)
    else:
        print("No pools_df found. Skipping pool upsert.")

except Exception as e:
    print(f"Database connection or upsert error: {e}")
finally:   
        conn.close()
        print("Database connection closed.")
# Out:
# Connected to Neon database successfully.
# Inserted 280 addresses successfully.
# Inserted 117 pools successfully.
# Database connection closed.

# %%
pools_df.head()
# Out:
#          lat        lon                                               tags
# 0  43.312810 -80.611900  {'access': 'private', 'building': 'yes', 'leis...
# 1  43.329218 -80.809291                       {'leisure': 'swimming_pool'}
# 2  43.328912 -80.807952                       {'leisure': 'swimming_pool'}
# 3  43.368118 -81.001000                       {'leisure': 'swimming_pool'}
# 4  43.370764 -80.975889   {'leisure': 'swimming_pool', 'natural': 'water'}
